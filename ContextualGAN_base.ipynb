# %%
from __future__ import print_function, division

from keras_contrib.layers.normalization.instancenormalization import InstanceNormalization
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, Concatenate, BatchNormalization, Activation, ZeroPadding2D
from keras.layers.advanced_activations import LeakyReLU
from keras.layers.convolutional import UpSampling2D, Conv2D
from keras.models import Sequential, Model
from keras.optimizers import Adam
from keras.layers import Lambda

from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img

import tensorflow as tf
import keras.backend as K
from keras.losses import mean_absolute_error

from sklearn.utils import shuffle
import matplotlib.pyplot as plt
import numpy as np
import datetime
import natsort
import scipy
import sys
import os
import cv2
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Helper Function

# %%
def load_filename(path):
    dirFiles = os.listdir(path)
    for i, file in enumerate(dirFiles):
        dirFiles[i] = path + file
    return natsort.natsorted(dirFiles ,reverse=False)

# load all images in a directory into memory
def load_images(list_path, size=(256, 256)):
    img_list = list()
    # enumerate filenames in directory, assume all are images
    for filename in list_path:
        # load and resize the image
        pixels = load_img(filename, target_size=size)
        # convert to numpy array
        pixels = img_to_array(pixels)
        pixels = (pixels - 127.5) / 127.5
        img_list.append(pixels)
    return np.asarray(img_list)

# %%
# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
    # unpack dataset
    trainA, trainB = dataset

    # choose random instances
    ix = np.random.randint(0, trainA.shape[0], n_samples)
    
    # retrieve selected images
    X1, X2 = trainA[ix], trainB[ix]
    
    # generate 'real' class labels (1)
    y = np.ones((n_samples, patch_shape, patch_shape, 1))
    
    return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
    # generate fake instance
    X = g_model.predict(samples)
    
    # create 'fake' class labels (0)
    y = np.zeros((len(X), patch_shape, patch_shape, 1))
    
    return X, y

# %%
# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, d_model, dataset, target_dir='', n_samples=3):
    if target_dir and not os.path.exists(target_dir):
        os.mkdir(target_dir)
    # select a sample of input images
    [X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
    # generate a batch of fake samples
    X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
    # scale all pixels from [-1,1] to [0,1]
    X_realA = (X_realA + 1) / 2.0
    X_realB = (X_realB + 1) / 2.0
    X_fakeB = (X_fakeB + 1) / 2.0
    # plot real source images
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + i)
        plt.axis('off')
        plt.imshow(X_realA[i])
    # plot generated target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples + i)
        plt.axis('off')
        plt.imshow(X_fakeB[i])
    # plot real target image
    for i in range(n_samples):
        plt.subplot(3, n_samples, 1 + n_samples*2 + i)
        plt.axis('off')
        plt.imshow(X_realB[i])
    # save plot to file
    filename1 = 'plot_%06d.png' % (step+1)
    plt.savefig(target_dir + filename1)
    plt.close()
    # save the generator model
    g_model.save(target_dir + 'g_model.h5')
    
    # save the discriminator model
    d_model.save(target_dir + 'd_model.h5')
    
    print('>Saved: %s and %s' % (filename1, 'g_model & d_model'))

# %% [markdown]
# ## Generator

# %%
def generator(img_shape):
    def conv2d(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d
    
    def deconv2d(layer_in, skip_in, n_filter, dropout=0.5):
        d = UpSampling2D(size=2)(layer_in)
        d = Conv2D(n_filter, kernel_size=4, strides=1, padding='same', activation='relu')(d)
        if dropout:
            d = Dropout(dropout)(d)
        d = InstanceNormalization()(d)
        d = Concatenate()([d, skip_in])
        return d
    
    # Input Layer
    in_img = Input(shape=img_shape)
    
    # Downsampling
    d1 = conv2d(in_img, 64, norm=False)
    d2 = conv2d(d1, 128)
    d3 = conv2d(d2, 256)
    d4 = conv2d(d3, 512)
    d5 = conv2d(d4, 512)
    d6 = conv2d(d5, 512)
    d7 = conv2d(d6, 512)
    
    # Upsampling
    u1 = deconv2d(d7, d6, 512)
    u2 = deconv2d(u1, d5, 512)
    u3 = deconv2d(u2, d4, 512)
    u4 = deconv2d(u3, d3, 256, dropout=0)
    u5 = deconv2d(u4, d2, 128, dropout=0)
    u6 = deconv2d(u5, d1, 64, dropout=0)
    u7 = UpSampling2D(size=2)(u6)
    out_img = Conv2D(3, kernel_size=4, strides=1, padding='same', activation='tanh')(u7)
    
    return Model(in_img, out_img, name='generator')

# %% [markdown]
# ## Discriminator

# %%
def discriminator(img_shape):
    def d_layer(layer_in, n_filter, norm=True):
        d = Conv2D(n_filter, kernel_size=4, strides=2, padding='same')(layer_in)
        d = LeakyReLU(0.2)(d)
        if norm:
            d = InstanceNormalization()(d)
        return d
    
    in_src_img = Input(shape=img_shape)
    in_target_img = Input(shape=img_shape)
    
    merged = Concatenate()([in_src_img, in_target_img])
    
    d1 = d_layer(merged, 64, norm=False)
    d2 = d_layer(d1, 128)
    d3 = d_layer(d1, 256)
    d4 = d_layer(d1, 512)

    out = Conv2D(1, kernel_size=4, strides=1, padding='same')(d4)
    
    return Model([in_src_img, in_target_img], out, name='discriminator')

# %% [markdown]
# ## GAN

# %%
def GAN(g_model, d_model, img_shape):
    d_model.trainable = False
    in_img = Input(shape=img_shape)
    gen_out = g_model(in_img)
    dis_out = d_model([in_img, gen_out])
    model = Model(in_img, [dis_out, gen_out], name='GAN')
    return model

# %% [markdown]
# ## Train GAN model

# %%
def train(d_model, g_model, gan_model, data, target_dir, n_epochs=100, n_batch=16):
    # determine the output square shape of the discriminator
    n_patch = d_model.output_shape[1]
    
    blue_photo = data[0]
    blue_sketch = data[1]
    
    for i in range(n_epochs):
        print(' ========== Epoch', i+1, '========== ')
        
        blue_photo, blue_sketch = shuffle(blue_photo, blue_sketch)

        for j in range(int(len(blue_photo)/n_batch)):
            
            start = int(j*n_batch)
            end = int(min(len(blue_photo), (j*n_batch)+n_batch))
            
            dataset = [load_images(blue_photo[start:end]), load_images(blue_sketch[start:end])]

            # select a batch of real samples
            [X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
            
            # generate a batch of fake samples
            X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
            
            # update discriminator for real samples
            d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
            
            # update discriminator for generated samples
            d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
            
            d_loss = 0.5 * np.add(d_loss1, d_loss2)
            
            # update the generator
            g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
            
            # summarize performance
            print('Batch : %d, D Loss : %.3f | G Loss : %.3f' % (j+1, d_loss, g_loss))
        
        # summarize model performance
#         if (i+1) % 10 == 0:
        summarize_performance(i, g_model, d_model, dataset, target_dir)

# %% [markdown]
# ## Loss Function

# %%
import tensorflow as tf
import keras.backend as K
from keras.losses import mean_absolute_error

def pixel_loss(y_true, y_pred):
    return K.mean(K.abs(y_true - y_pred))

def contextual_loss (y_true, y_pred):
    a = tf.image.rgb_to_grayscale(tf.slice(
                                y_pred, 
                                [0,0,0,0], 
                                [16, 256, 256, 3]))
    
    b = tf.image.rgb_to_grayscale(tf.slice(
                                y_true, 
                                [0,0,0,0], 
                                [16, 256, 256, 3]))
    
    y_pred = tf.divide(tf.add(tf.reshape(a, [tf.shape(a)[0], -1]), 1), 2)
    y_true = tf.divide(tf.add(tf.reshape(b, [tf.shape(b)[0], -1]), 1), 2)
    
#     tf.assert_rank(y_true,2)
#     tf.assert_rank(y_pred,2)
    
    p_shape = tf.shape(y_true)
    q_shape = tf.shape(y_pred)
#     tf.assert_equal(p_shape, q_shape)
    
    # normalize sum to 1
    p_ = tf.divide(y_true, tf.tile(tf.expand_dims(tf.reduce_sum(y_true, axis=1), 1), [1,p_shape[1]]))
    q_ = tf.divide(y_pred, tf.tile(tf.expand_dims(tf.reduce_sum(y_pred, axis=1), 1), [1,p_shape[1]]))
    
    return tf.reduce_sum(tf.multiply(p_, tf.log(tf.divide(p_, q_))), axis=1)

def total_loss (y_true, y_pred):

    px_loss = pixel_loss(y_true, y_pred)

    ctx_loss = contextual_loss(y_true, y_pred)
    
    return (0.2 * px_loss) + (0.8 * ctx_loss)

# %% [markdown]
# ## Load Dataset

# %%
# dataset path
b_photo_path = 'Dataset/Augmented photo/'
b_sketch_path = 'Dataset/Augmented sketch/'

blue_photo = load_filename(b_photo_path)
blue_sketch = load_filename(b_sketch_path)

# %%
plt.imshow(cv2.cvtColor(cv2.imread(blue_photo[1102]).astype('uint8'), cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(cv2.imread(blue_sketch[1102]).astype('uint8'), cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Define GAN Model

# %%
img_shape = (256, 256, 3)

d_model = discriminator(img_shape)

g_model = generator(img_shape)

gan_model = GAN(g_model, d_model, img_shape)
# Out:
# WARNING:tensorflow:From /home/ikun/anaconda3/envs/gan/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
gan_model.summary()
# Out:
# Model: "GAN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# generator (Model)               (None, 256, 256, 3)  41825691    input_4[0][0]
# __________________________________________________________________________________________________
# discriminator (Model)           (None, 64, 64, 1)    539203      input_4[0][0]
#                                                                  generator[1][0]
# ==================================================================================================
# Total params: 42,364,894
# Trainable params: 41,825,691
# Non-trainable params: 539,203
# __________________________________________________________________________________________________

# %%
opt = Adam(lr=2e-4, beta_1=0.5)

d_model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
gan_model.compile(loss=['binary_crossentropy', total_loss], optimizer=opt, loss_weights=[1,100])

# %% [markdown]
# ## Start Training

# %%
train(d_model, g_model, gan_model, [blue_sketch, blue_photo], 'Models/Pixel[02]_Context[08]/', n_epochs = 100, n_batch=16)
# Out:
#  ========== Epoch 1 ==========
# WARNING:tensorflow:From /home/ikun/anaconda3/envs/gan/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/ikun/anaconda3/envs/gan/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Batch : 1, D Loss : 3.374 | G Loss : 21.371
# Batch : 2, D Loss : 3.433 | G Loss : 13.507
# Batch : 3, D Loss : 2.759 | G Loss : 15.251
# Batch : 4, D Loss : 3.149 | G Loss : 11.136
# Batch : 5, D Loss : 3.197 | G Loss : 9.895
# Batch : 6, D Loss : 2.877 | G Loss : 12.851
# Batch : 7, D Loss : 3.272 | G Loss : 8.439
# Batch : 8, D Loss : 3.354 | G Loss : 10.461
# Batch : 9, D Loss : 3.199 | G Loss : 8.756
# Batch : 10, D Loss : 3.003 | G Loss : 10.474
# Batch : 11, D Loss : 3.209 | G Loss : 10.926
# Batch : 12, D Loss : 3.145 | G Loss : 9.542
# Batch : 13, D Loss : 3.319 | G Loss : 9.378
# Batch : 14, D Loss : 3.332 | G Loss : 9.633
# Batch : 15, D Loss : 3.389 | G Loss : 7.633
# Batch : 16, D Loss : 3.439 | G Loss : 8.456
# Batch : 17, D Loss : 3.314 | G Loss : 8.663
# Batch : 18, D Loss : 3.305 | G Loss : 7.680
# Batch : 19, D Loss : 3.465 | G Loss : 8.511
# Batch : 20, D Loss : 3.440 | G Loss : 6.085
# Batch : 21, D Loss : 3.295 | G Loss : 8.040
# Batch : 22, D Loss : 3.320 | G Loss : 7.927
# Batch : 23, D Loss : 3.322 | G Loss : 6.907
# Batch : 24, D Loss : 3.295 | G Loss : 7.670
# Batch : 25, D Loss : 3.322 | G Loss : 7.767
# Batch : 26, D Loss : 3.393 | G Loss : 8.015
# Batch : 27, D Loss : 3.439 | G Loss : 6.342
# Batch : 28, D Loss : 3.444 | G Loss : 6.397
# Batch : 29, D Loss : 3.395 | G Loss : 6.302
# Batch : 30, D Loss : 3.310 | G Loss : 7.260
# Batch : 31, D Loss : 3.509 | G Loss : 6.252
# Batch : 32, D Loss : 3.404 | G Loss : 6.156
# Batch : 33, D Loss : 3.330 | G Loss : 6.150
# Batch : 34, D Loss : 3.438 | G Loss : 6.019
# Batch : 35, D Loss : 3.379 | G Loss : 5.663
# Batch : 36, D Loss : 3.362 | G Loss : 6.388
# Batch : 37, D Loss : 3.489 | G Loss : 6.697
# Batch : 38, D Loss : 3.350 | G Loss : 5.825
# Batch : 39, D Loss : 3.286 | G Loss : 7.723
# Batch : 40, D Loss : 3.393 | G Loss : 7.142
# Batch : 41, D Loss : 3.399 | G Loss : 6.920
# Batch : 42, D Loss : 3.419 | G Loss : 5.267
# Batch : 43, D Loss : 3.407 | G Loss : 5.649
# Batch : 44, D Loss : 3.304 | G Loss : 6.391
# Batch : 45, D Loss : 3.277 | G Loss : 6.105
# Batch : 46, D Loss : 3.373 | G Loss : 6.712
# Batch : 47, D Loss : 3.302 | G Loss : 7.275
# Batch : 48, D Loss : 3.340 | G Loss : 5.842
# Batch : 49, D Loss : 3.338 | G Loss : 5.740
# Batch : 50, D Loss : 3.426 | G Loss : 5.969
# Batch : 51, D Loss : 3.488 | G Loss : 5.005
# Batch : 52, D Loss : 3.341 | G Loss : 7.717
# Batch : 53, D Loss : 3.329 | G Loss : 7.241
# Batch : 54, D Loss : 3.350 | G Loss : 6.722
# Batch : 55, D Loss : 3.409 | G Loss : 6.998
# Batch : 56, D Loss : 3.373 | G Loss : 8.283
# Batch : 57, D Loss : 3.358 | G Loss : 8.732
# Batch : 58, D Loss : 3.454 | G Loss : 9.124
# Batch : 59, D Loss : 3.358 | G Loss : 8.175
# Batch : 60, D Loss : 3.301 | G Loss : 8.707
# Batch : 61, D Loss : 3.434 | G Loss : 7.972
# Batch : 62, D Loss : 3.351 | G Loss : 6.931
# Batch : 63, D Loss : 3.284 | G Loss : 7.452
# Batch : 64, D Loss : 3.363 | G Loss : 7.666
# Batch : 65, D Loss : 3.300 | G Loss : 6.656
# Batch : 66, D Loss : 3.238 | G Loss : 7.839
# Batch : 67, D Loss : 3.214 | G Loss : 6.334
# Batch : 68, D Loss : 3.446 | G Loss : 6.830
# Batch : 69, D Loss : 3.253 | G Loss : 5.356
# Batch : 70, D Loss : 3.222 | G Loss : 5.504
# Batch : 71, D Loss : 3.441 | G Loss : 5.281
# Batch : 72, D Loss : 3.404 | G Loss : 4.984
# Batch : 73, D Loss : 3.398 | G Loss : 6.039
# Batch : 74, D Loss : 3.377 | G Loss : 5.076
# Batch : 75, D Loss : 3.420 | G Loss : 5.284
# Batch : 76, D Loss : 3.223 | G Loss : 6.032
# Batch : 77, D Loss : 3.363 | G Loss : 4.548
# Batch : 78, D Loss : 3.422 | G Loss : 4.705
# Batch : 79, D Loss : 3.393 | G Loss : 5.355
# Batch : 80, D Loss : 3.280 | G Loss : 5.025
# Batch : 81, D Loss : 3.350 | G Loss : 4.540
# Batch : 82, D Loss : 3.311 | G Loss : 4.532
# Batch : 83, D Loss : 3.547 | G Loss : 4.763
# Batch : 84, D Loss : 3.554 | G Loss : 5.855
# Batch : 85, D Loss : 3.588 | G Loss : 4.767
# Batch : 86, D Loss : 3.539 | G Loss : 5.045
# Batch : 87, D Loss : 3.496 | G Loss : 5.035
# Batch : 88, D Loss : 3.547 | G Loss : 4.750
# Batch : 89, D Loss : 3.497 | G Loss : 4.194
# Batch : 90, D Loss : 3.546 | G Loss : 4.355
# Batch : 91, D Loss : 3.461 | G Loss : 3.837
# Batch : 92, D Loss : 3.430 | G Loss : 4.709
# Batch : 93, D Loss : 3.451 | G Loss : 5.364
# Batch : 94, D Loss : 3.438 | G Loss : 3.689
# Batch : 95, D Loss : 3.375 | G Loss : 4.083
# Batch : 96, D Loss : 3.455 | G Loss : 5.458
# Batch : 97, D Loss : 3.336 | G Loss : 5.877
# Batch : 98, D Loss : 3.433 | G Loss : 3.946
# Batch : 99, D Loss : 3.447 | G Loss : 3.940
# Batch : 100, D Loss : 3.417 | G Loss : 3.973
# Batch : 101, D Loss : 3.311 | G Loss : 4.850
# Batch : 102, D Loss : 3.411 | G Loss : 4.565
# Batch : 103, D Loss : 3.377 | G Loss : 4.937
# Batch : 104, D Loss : 3.418 | G Loss : 4.612
# Batch : 105, D Loss : 3.387 | G Loss : 4.374
# Batch : 106, D Loss : 3.426 | G Loss : 3.816
# Batch : 107, D Loss : 3.359 | G Loss : 4.042
# Batch : 108, D Loss : 3.329 | G Loss : 3.696
# Batch : 109, D Loss : 3.471 | G Loss : 4.028
# Batch : 110, D Loss : 3.285 | G Loss : 5.675
# Batch : 111, D Loss : 3.290 | G Loss : 4.633
# Batch : 112, D Loss : 3.401 | G Loss : 5.007
# Batch : 113, D Loss : 3.426 | G Loss : 3.973
# Batch : 114, D Loss : 3.280 | G Loss : 4.627
# Batch : 115, D Loss : 3.326 | G Loss : 3.984
# Batch : 116, D Loss : 3.320 | G Loss : 4.637
# Batch : 117, D Loss : 3.380 | G Loss : 3.693
# Batch : 118, D Loss : 3.318 | G Loss : 3.873
# Batch : 119, D Loss : 3.308 | G Loss : 4.407
# Batch : 120, D Loss : 3.429 | G Loss : 3.992
# Batch : 121, D Loss : 3.353 | G Loss : 4.390
# Batch : 122, D Loss : 3.327 | G Loss : 4.119
# Batch : 123, D Loss : 3.305 | G Loss : 4.405
# Batch : 124, D Loss : 3.440 | G Loss : 4.218
# Batch : 125, D Loss : 3.350 | G Loss : 4.199
# Batch : 126, D Loss : 3.411 | G Loss : 3.863
# Batch : 127, D Loss : 3.466 | G Loss : 4.203
# Batch : 128, D Loss : 3.306 | G Loss : 3.861
# Batch : 129, D Loss : 3.374 | G Loss : 4.043
# Batch : 130, D Loss : 3.315 | G Loss : 4.385
# Batch : 131, D Loss : 3.330 | G Loss : 3.988
# Batch : 132, D Loss : 3.388 | G Loss : 3.112
# Batch : 133, D Loss : 3.358 | G Loss : 3.914
# Batch : 134, D Loss : 3.255 | G Loss : 4.274
# Batch : 135, D Loss : 3.432 | G Loss : 3.285
# Batch : 136, D Loss : 3.313 | G Loss : 4.362
# Batch : 137, D Loss : 3.407 | G Loss : 3.915
# Batch : 138, D Loss : 3.353 | G Loss : 4.517
# Batch : 139, D Loss : 3.371 | G Loss : 3.953
# Batch : 140, D Loss : 3.339 | G Loss : 3.777
# Batch : 141, D Loss : 3.353 | G Loss : 3.471
# Batch : 142, D Loss : 3.386 | G Loss : 3.817
# Batch : 143, D Loss : 3.279 | G Loss : 4.527
# Batch : 144, D Loss : 3.315 | G Loss : 3.702
# Batch : 145, D Loss : 3.437 | G Loss : 4.801
# Batch : 146, D Loss : 3.321 | G Loss : 4.457
# Batch : 147, D Loss : 3.368 | G Loss : 3.664
# Batch : 148, D Loss : 3.381 | G Loss : 4.715
# Batch : 149, D Loss : 3.395 | G Loss : 4.528
# Batch : 150, D Loss : 3.370 | G Loss : 4.428
# Batch : 151, D Loss : 3.402 | G Loss : 3.926
# Batch : 152, D Loss : 3.336 | G Loss : 4.313
# Batch : 153, D Loss : 3.304 | G Loss : 3.984
# Batch : 154, D Loss : 3.369 | G Loss : 3.755
# Batch : 155, D Loss : 3.358 | G Loss : 4.234
# Batch : 156, D Loss : 3.431 | G Loss : 3.265
# Batch : 157, D Loss : 3.367 | G Loss : 3.818
# Batch : 158, D Loss : 3.392 | G Loss : 3.413
# Batch : 159, D Loss : 3.388 | G Loss : 4.313
# Batch : 160, D Loss : 3.356 | G Loss : 3.569
# Batch : 161, D Loss : 3.327 | G Loss : 4.394
# Batch : 162, D Loss : 3.392 | G Loss : 3.924
# Batch : 163, D Loss : 3.329 | G Loss : 4.190
# Batch : 164, D Loss : 3.393 | G Loss : 3.663
# Batch : 165, D Loss : 3.416 | G Loss : 4.441
# Batch : 166, D Loss : 3.424 | G Loss : 3.880
# Batch : 167, D Loss : 3.446 | G Loss : 3.957
# Batch : 168, D Loss : 3.283 | G Loss : 4.603
# Batch : 169, D Loss : 3.449 | G Loss : 10.814
# Batch : 170, D Loss : 3.359 | G Loss : 11.399
# Batch : 171, D Loss : 3.331 | G Loss : 7.916
# Batch : 172, D Loss : 3.327 | G Loss : 9.252
# Batch : 173, D Loss : 3.179 | G Loss : 9.882
# Batch : 174, D Loss : 3.256 | G Loss : 8.827
# Batch : 175, D Loss : 3.359 | G Loss : 8.178
# Batch : 176, D Loss : 3.338 | G Loss : 7.963
# Batch : 177, D Loss : 3.408 | G Loss : 6.238
# Batch : 178, D Loss : 3.385 | G Loss : 8.175
# Batch : 179, D Loss : 3.403 | G Loss : 7.412
# Batch : 180, D Loss : 3.364 | G Loss : 6.295
# Batch : 181, D Loss : 3.328 | G Loss : 6.978
# Batch : 182, D Loss : 3.336 | G Loss : 5.223
# Batch : 183, D Loss : 3.234 | G Loss : 5.839
# Batch : 184, D Loss : 3.413 | G Loss : 5.780
# Batch : 185, D Loss : 3.257 | G Loss : 4.199
# Batch : 186, D Loss : 3.307 | G Loss : 4.944
# Batch : 187, D Loss : 3.385 | G Loss : 4.918
# Batch : 188, D Loss : 3.466 | G Loss : 4.589
# Batch : 189, D Loss : 3.248 | G Loss : 6.492
# Batch : 190, D Loss : 3.442 | G Loss : 4.958
# Batch : 191, D Loss : 3.336 | G Loss : 5.738
# Batch : 192, D Loss : 3.465 | G Loss : 4.654
# Batch : 193, D Loss : 3.452 | G Loss : 4.502
# Batch : 194, D Loss : 3.383 | G Loss : 4.522
# Batch : 195, D Loss : 3.302 | G Loss : 4.414
# Batch : 196, D Loss : 3.392 | G Loss : 4.501
# Batch : 197, D Loss : 3.319 | G Loss : 4.597
# Batch : 198, D Loss : 3.409 | G Loss : 4.007
# Batch : 199, D Loss : 3.355 | G Loss : 4.625
# Batch : 200, D Loss : 3.404 | G Loss : 4.429
# Batch : 201, D Loss : 3.343 | G Loss : 4.834
# Batch : 202, D Loss : 3.333 | G Loss : 3.815
# Batch : 203, D Loss : 3.413 | G Loss : 3.982
# Batch : 204, D Loss : 3.275 | G Loss : 4.552
# Batch : 205, D Loss : 3.394 | G Loss : 4.304
# Batch : 206, D Loss : 3.342 | G Loss : 3.989
# Batch : 207, D Loss : 3.373 | G Loss : 4.623
# Batch : 208, D Loss : 3.354 | G Loss : 4.198
# Batch : 209, D Loss : 3.345 | G Loss : 4.051
# Batch : 210, D Loss : 3.468 | G Loss : 5.261
# Batch : 211, D Loss : 3.365 | G Loss : 4.023
# Batch : 212, D Loss : 3.269 | G Loss : 5.937
# Batch : 213, D Loss : 3.483 | G Loss : 4.385
# Batch : 214, D Loss : 3.390 | G Loss : 5.316
# Batch : 215, D Loss : 3.430 | G Loss : 4.828
# Batch : 216, D Loss : 3.405 | G Loss : 4.804
# Batch : 217, D Loss : 3.300 | G Loss : 4.117
# Batch : 218, D Loss : 3.384 | G Loss : 3.766
# Batch : 219, D Loss : 3.424 | G Loss : 4.591
# Batch : 220, D Loss : 3.401 | G Loss : 4.077
# Batch : 221, D Loss : 3.427 | G Loss : 3.807
# Batch : 222, D Loss : 3.338 | G Loss : 3.918
# Batch : 223, D Loss : 3.420 | G Loss : 4.093
# Batch : 224, D Loss : 3.359 | G Loss : 3.738
# Batch : 225, D Loss : 3.365 | G Loss : 4.101
# Batch : 226, D Loss : 3.363 | G Loss : 4.261
# Batch : 227, D Loss : 3.378 | G Loss : 4.119
# Batch : 228, D Loss : 3.291 | G Loss : 4.582
# Batch : 229, D Loss : 3.409 | G Loss : 3.957
# Batch : 230, D Loss : 3.438 | G Loss : 3.995
# Batch : 231, D Loss : 3.406 | G Loss : 3.979
# Batch : 232, D Loss : 3.339 | G Loss : 4.210
# Batch : 233, D Loss : 3.398 | G Loss : 3.396
# Batch : 234, D Loss : 3.396 | G Loss : 3.735
# Batch : 235, D Loss : 3.399 | G Loss : 3.292
# Batch : 236, D Loss : 3.329 | G Loss : 4.290
# Batch : 237, D Loss : 3.390 | G Loss : 4.350
# Batch : 238, D Loss : 3.404 | G Loss : 3.951
# Batch : 239, D Loss : 3.371 | G Loss : 4.427
# Batch : 240, D Loss : 3.363 | G Loss : 4.075
# Batch : 241, D Loss : 3.315 | G Loss : 4.512
# Batch : 242, D Loss : 3.417 | G Loss : 3.322
# Batch : 243, D Loss : 3.358 | G Loss : 4.807
# Batch : 244, D Loss : 3.368 | G Loss : 3.618
# Batch : 245, D Loss : 3.470 | G Loss : 3.885
# Batch : 246, D Loss : 3.412 | G Loss : 4.243
# Batch : 247, D Loss : 3.446 | G Loss : 3.726
# Batch : 248, D Loss : 3.406 | G Loss : 4.417
# Batch : 249, D Loss : 3.453 | G Loss : 3.532
# Batch : 250, D Loss : 3.349 | G Loss : 4.470
# Batch : 251, D Loss : 3.427 | G Loss : 3.859
# Batch : 252, D Loss : 3.356 | G Loss : 3.890
# Batch : 253, D Loss : 3.391 | G Loss : 3.335
# Batch : 254, D Loss : 3.346 | G Loss : 3.914
# Batch : 255, D Loss : 3.394 | G Loss : 3.940
# Batch : 256, D Loss : 3.383 | G Loss : 3.520
# Batch : 257, D Loss : 3.370 | G Loss : 3.964
# Batch : 258, D Loss : 3.371 | G Loss : 4.108
# Batch : 259, D Loss : 3.383 | G Loss : 3.397
# Batch : 260, D Loss : 3.364 | G Loss : 3.339
# Batch : 261, D Loss : 3.305 | G Loss : 4.091
# Batch : 262, D Loss : 3.333 | G Loss : 3.793
# Batch : 263, D Loss : 3.393 | G Loss : 4.006
# Batch : 264, D Loss : 3.305 | G Loss : 3.842
# Batch : 265, D Loss : 3.346 | G Loss : 4.803
# Batch : 266, D Loss : 3.339 | G Loss : 4.013
# Batch : 267, D Loss : 3.455 | G Loss : 4.060
# Batch : 268, D Loss : 3.330 | G Loss : 4.378
# Batch : 269, D Loss : 3.372 | G Loss : 3.608
# Batch : 270, D Loss : 3.337 | G Loss : 4.560
# Batch : 271, D Loss : 3.518 | G Loss : 3.827
# Batch : 272, D Loss : 3.400 | G Loss : 3.767
# Batch : 273, D Loss : 3.420 | G Loss : 3.973
# Batch : 274, D Loss : 3.423 | G Loss : 3.851
# Batch : 275, D Loss : 3.274 | G Loss : 3.839
# Batch : 276, D Loss : 3.324 | G Loss : 3.658
# Batch : 277, D Loss : 3.333 | G Loss : 3.629
# Batch : 278, D Loss : 3.449 | G Loss : 3.141
# Batch : 279, D Loss : 3.439 | G Loss : 3.341
# Batch : 280, D Loss : 3.371 | G Loss : 3.687
# Batch : 281, D Loss : 3.315 | G Loss : 3.402
# Batch : 282, D Loss : 3.461 | G Loss : 3.792
# Batch : 283, D Loss : 3.333 | G Loss : 3.713
# Batch : 284, D Loss : 3.444 | G Loss : 3.411
# Batch : 285, D Loss : 3.396 | G Loss : 4.176
# Batch : 286, D Loss : 3.411 | G Loss : 3.513
# Batch : 287, D Loss : 3.338 | G Loss : 3.448
# Batch : 288, D Loss : 3.370 | G Loss : 3.239
# Batch : 289, D Loss : 3.338 | G Loss : 3.498
# Batch : 290, D Loss : 3.382 | G Loss : 3.572
# Batch : 291, D Loss : 3.377 | G Loss : 3.533
# Batch : 292, D Loss : 3.398 | G Loss : 3.814
# Batch : 293, D Loss : 3.428 | G Loss : 3.351
# Batch : 294, D Loss : 3.479 | G Loss : 3.408
# Batch : 295, D Loss : 3.503 | G Loss : 4.293
# Batch : 296, D Loss : 3.456 | G Loss : 3.880
# Batch : 297, D Loss : 3.453 | G Loss : 3.300
# Batch : 298, D Loss : 3.364 | G Loss : 4.390
# Batch : 299, D Loss : 3.451 | G Loss : 3.672
# Batch : 300, D Loss : 3.420 | G Loss : 3.917
# Batch : 301, D Loss : 3.406 | G Loss : 3.867
# Batch : 302, D Loss : 3.340 | G Loss : 3.832
# Batch : 303, D Loss : 3.384 | G Loss : 4.013
# Batch : 304, D Loss : 3.400 | G Loss : 4.298
# Batch : 305, D Loss : 3.387 | G Loss : 3.575
# Batch : 306, D Loss : 3.343 | G Loss : 3.351
# Batch : 307, D Loss : 3.320 | G Loss : 3.614
# Batch : 308, D Loss : 3.391 | G Loss : 3.798
# Batch : 309, D Loss : 3.341 | G Loss : 4.165
# Batch : 310, D Loss : 3.367 | G Loss : 3.323
# Batch : 311, D Loss : 3.354 | G Loss : 3.929
# Batch : 312, D Loss : 3.366 | G Loss : 3.489
# Batch : 313, D Loss : 3.278 | G Loss : 4.062
# Batch : 314, D Loss : 3.365 | G Loss : 3.641
# Batch : 315, D Loss : 3.305 | G Loss : 3.482
# Batch : 316, D Loss : 3.396 | G Loss : 5.439
# Batch : 317, D Loss : 3.384 | G Loss : 3.836
# Batch : 318, D Loss : 3.398 | G Loss : 3.595
# Batch : 319, D Loss : 3.367 | G Loss : 3.413
# Batch : 320, D Loss : 3.332 | G Loss : 3.723
# Batch : 321, D Loss : 3.292 | G Loss : 3.672
# Batch : 322, D Loss : 3.393 | G Loss : 3.678
# Batch : 323, D Loss : 3.419 | G Loss : 3.348
# Batch : 324, D Loss : 3.428 | G Loss : 3.366
# Batch : 325, D Loss : 3.347 | G Loss : 4.295
# Batch : 326, D Loss : 3.325 | G Loss : 3.374
# Batch : 327, D Loss : 3.341 | G Loss : 3.710
# Batch : 328, D Loss : 3.423 | G Loss : 3.234
# Batch : 329, D Loss : 3.411 | G Loss : 3.991
# Batch : 330, D Loss : 3.369 | G Loss : 3.074
# Batch : 331, D Loss : 3.403 | G Loss : 3.506
# Batch : 332, D Loss : 3.355 | G Loss : 3.869
# Batch : 333, D Loss : 3.359 | G Loss : 3.233
# Batch : 334, D Loss : 3.348 | G Loss : 3.326
# Batch : 335, D Loss : 3.292 | G Loss : 3.542
# Batch : 336, D Loss : 3.304 | G Loss : 3.181
# Batch : 337, D Loss : 3.309 | G Loss : 3.529
# Batch : 338, D Loss : 3.351 | G Loss : 4.441
# Batch : 339, D Loss : 3.388 | G Loss : 3.276
# Batch : 340, D Loss : 3.374 | G Loss : 3.566
# Batch : 341, D Loss : 3.313 | G Loss : 3.607
# Batch : 342, D Loss : 3.397 | G Loss : 3.716
# Batch : 343, D Loss : 3.360 | G Loss : 3.640
# Batch : 344, D Loss : 3.349 | G Loss : 3.656
# Batch : 345, D Loss : 3.423 | G Loss : 3.245
# Batch : 346, D Loss : 3.324 | G Loss : 3.348
# Batch : 347, D Loss : 3.321 | G Loss : 3.713
# Batch : 348, D Loss : 3.354 | G Loss : 3.531
# Batch : 349, D Loss : 3.419 | G Loss : 3.980
# Batch : 350, D Loss : 3.307 | G Loss : 3.236
# Batch : 351, D Loss : 3.369 | G Loss : 3.445
# Batch : 352, D Loss : 3.294 | G Loss : 4.754
# Batch : 353, D Loss : 3.438 | G Loss : 3.571
# Batch : 354, D Loss : 3.432 | G Loss : 3.308
# Batch : 355, D Loss : 3.421 | G Loss : 3.084
# Batch : 356, D Loss : 3.391 | G Loss : 3.497
# Batch : 357, D Loss : 3.353 | G Loss : 3.373
# Batch : 358, D Loss : 3.336 | G Loss : 3.442
# Batch : 359, D Loss : 3.387 | G Loss : 3.575
# Batch : 360, D Loss : 3.315 | G Loss : 3.755
# Batch : 361, D Loss : 3.447 | G Loss : 3.366
# Batch : 362, D Loss : 3.407 | G Loss : 2.904
# Batch : 363, D Loss : 3.324 | G Loss : 3.927
# Batch : 364, D Loss : 3.426 | G Loss : 2.875
# Batch : 365, D Loss : 3.383 | G Loss : 3.778
# Batch : 366, D Loss : 3.386 | G Loss : 3.818
# Batch : 367, D Loss : 3.414 | G Loss : 3.770
# Batch : 368, D Loss : 3.373 | G Loss : 3.236
# Batch : 369, D Loss : 3.340 | G Loss : 3.741
# Batch : 370, D Loss : 3.395 | G Loss : 3.487
# Batch : 371, D Loss : 3.332 | G Loss : 3.616
# Batch : 372, D Loss : 3.320 | G Loss : 3.525
# Batch : 373, D Loss : 3.376 | G Loss : 2.976
# Batch : 374, D Loss : 3.228 | G Loss : 4.271
# Batch : 375, D Loss : 3.399 | G Loss : 3.718
# Batch : 376, D Loss : 3.420 | G Loss : 3.764
# Batch : 377, D Loss : 3.398 | G Loss : 3.385
# Batch : 378, D Loss : 3.356 | G Loss : 4.045
# Batch : 379, D Loss : 3.423 | G Loss : 4.039
# Batch : 380, D Loss : 3.429 | G Loss : 3.466
# Batch : 381, D Loss : 3.341 | G Loss : 3.940
# Batch : 382, D Loss : 3.414 | G Loss : 3.613
# Batch : 383, D Loss : 3.372 | G Loss : 3.392
# Batch : 384, D Loss : 3.366 | G Loss : 3.381
# Batch : 385, D Loss : 3.440 | G Loss : 3.364
# Batch : 386, D Loss : 3.435 | G Loss : 3.923
# Batch : 387, D Loss : 3.428 | G Loss : 2.878
# Batch : 388, D Loss : 3.447 | G Loss : 3.852
# Batch : 389, D Loss : 3.432 | G Loss : 2.969
# Batch : 390, D Loss : 3.348 | G Loss : 3.434
# Batch : 391, D Loss : 3.341 | G Loss : 3.592
# Batch : 392, D Loss : 3.344 | G Loss : 3.878
# Batch : 393, D Loss : 3.427 | G Loss : 2.952
# Batch : 394, D Loss : 3.286 | G Loss : 3.367
# Batch : 395, D Loss : 3.371 | G Loss : 3.406
# Batch : 396, D Loss : 3.406 | G Loss : 3.362
# Batch : 397, D Loss : 3.393 | G Loss : 3.234
# Batch : 398, D Loss : 3.347 | G Loss : 4.121
# Batch : 399, D Loss : 3.368 | G Loss : 3.541
# Batch : 400, D Loss : 3.365 | G Loss : 3.426
# Batch : 401, D Loss : 3.332 | G Loss : 4.662
# Batch : 402, D Loss : 3.409 | G Loss : 3.250
# Batch : 403, D Loss : 3.347 | G Loss : 3.498
# Batch : 404, D Loss : 3.372 | G Loss : 3.403
# Batch : 405, D Loss : 3.348 | G Loss : 3.310
# Batch : 406, D Loss : 3.422 | G Loss : 3.440
# Batch : 407, D Loss : 3.334 | G Loss : 3.437
# Batch : 408, D Loss : 3.338 | G Loss : 2.965
# Batch : 409, D Loss : 3.331 | G Loss : 3.377
# Batch : 410, D Loss : 3.403 | G Loss : 3.773
# Batch : 411, D Loss : 3.389 | G Loss : 3.186
# Batch : 412, D Loss : 3.356 | G Loss : 4.037
# Batch : 413, D Loss : 3.386 | G Loss : 3.378
# Batch : 414, D Loss : 3.399 | G Loss : 3.026
# Batch : 415, D Loss : 3.392 | G Loss : 3.208
# Batch : 416, D Loss : 3.383 | G Loss : 3.580
# Batch : 417, D Loss : 3.390 | G Loss : 2.828
# Batch : 418, D Loss : 3.311 | G Loss : 3.710
# Batch : 419, D Loss : 3.407 | G Loss : 2.915
# Batch : 420, D Loss : 3.336 | G Loss : 3.609
# Batch : 421, D Loss : 3.409 | G Loss : 3.162
# Batch : 422, D Loss : 3.324 | G Loss : 3.148
# Batch : 423, D Loss : 3.321 | G Loss : 3.428
# Batch : 424, D Loss : 3.249 | G Loss : 3.366
# Batch : 425, D Loss : 3.310 | G Loss : 3.388
# Batch : 426, D Loss : 3.404 | G Loss : 3.342
# Batch : 427, D Loss : 3.429 | G Loss : 3.440
# Batch : 428, D Loss : 3.350 | G Loss : 3.796
# Batch : 429, D Loss : 3.362 | G Loss : 3.799
# Batch : 430, D Loss : 3.408 | G Loss : 3.339
# Batch : 431, D Loss : 3.312 | G Loss : 3.239
# Batch : 432, D Loss : 3.318 | G Loss : 3.585
# Batch : 433, D Loss : 3.371 | G Loss : 3.275
# Batch : 434, D Loss : 3.477 | G Loss : 3.544
# Batch : 435, D Loss : 3.348 | G Loss : 3.788
# Batch : 436, D Loss : 3.376 | G Loss : 3.754
# Batch : 437, D Loss : 3.350 | G Loss : 3.148
# Batch : 438, D Loss : 3.345 | G Loss : 3.436
# Batch : 439, D Loss : 3.338 | G Loss : 4.265
# Batch : 440, D Loss : 3.428 | G Loss : 3.452
# Batch : 441, D Loss : 3.348 | G Loss : 3.879
# Batch : 442, D Loss : 3.370 | G Loss : 4.074
# Batch : 443, D Loss : 3.384 | G Loss : 3.537
# Batch : 444, D Loss : 3.423 | G Loss : 3.007
# Batch : 445, D Loss : 3.388 | G Loss : 3.104
# Batch : 446, D Loss : 3.313 | G Loss : 3.615
# Batch : 447, D Loss : 3.284 | G Loss : 3.370
# Batch : 448, D Loss : 3.260 | G Loss : 3.134
# Batch : 449, D Loss : 3.286 | G Loss : 3.392
# Batch : 450, D Loss : 3.405 | G Loss : 3.127
# Batch : 451, D Loss : 3.338 | G Loss : 3.342
# Batch : 452, D Loss : 3.401 | G Loss : 3.098
# Batch : 453, D Loss : 3.338 | G Loss : 3.196
# Batch : 454, D Loss : 3.361 | G Loss : 3.255
# Batch : 455, D Loss : 3.337 | G Loss : 3.018
# Batch : 456, D Loss : 3.257 | G Loss : 3.315
# Batch : 457, D Loss : 3.302 | G Loss : 3.317
# Batch : 458, D Loss : 3.367 | G Loss : 4.094
# Batch : 459, D Loss : 3.422 | G Loss : 3.229
# Batch : 460, D Loss : 3.403 | G Loss : 3.207
# Batch : 461, D Loss : 3.424 | G Loss : 3.469
# Batch : 462, D Loss : 3.364 | G Loss : 3.810
# Batch : 463, D Loss : 3.304 | G Loss : 3.161
# Batch : 464, D Loss : 3.270 | G Loss : 3.029
# Batch : 465, D Loss : 3.302 | G Loss : 3.427
# Batch : 466, D Loss : 3.292 | G Loss : 3.479
# Batch : 467, D Loss : 3.354 | G Loss : 3.923
# Batch : 468, D Loss : 3.415 | G Loss : 3.308
# Batch : 469, D Loss : 3.429 | G Loss : 3.139
# Batch : 470, D Loss : 3.394 | G Loss : 3.056
# Batch : 471, D Loss : 3.367 | G Loss : 3.306
# Batch : 472, D Loss : 3.366 | G Loss : 3.294
# Batch : 473, D Loss : 3.413 | G Loss : 3.331
# Batch : 474, D Loss : 3.360 | G Loss : 3.374
# Batch : 475, D Loss : 3.244 | G Loss : 3.929
# Batch : 476, D Loss : 3.301 | G Loss : 3.609
# Batch : 477, D Loss : 3.387 | G Loss : 3.095
# Batch : 478, D Loss : 3.378 | G Loss : 3.671
# Batch : 479, D Loss : 3.354 | G Loss : 3.460
# Batch : 480, D Loss : 3.350 | G Loss : 2.945
# Batch : 481, D Loss : 3.241 | G Loss : 3.523
# Batch : 482, D Loss : 3.415 | G Loss : 3.075
# Batch : 483, D Loss : 3.336 | G Loss : 3.380
# Batch : 484, D Loss : 3.357 | G Loss : 2.816
# Batch : 485, D Loss : 3.303 | G Loss : 3.434
# Batch : 486, D Loss : 3.348 | G Loss : 3.202
# Batch : 487, D Loss : 3.413 | G Loss : 2.723
# Batch : 488, D Loss : 3.364 | G Loss : 3.669
# Batch : 489, D Loss : 3.376 | G Loss : 3.465
# Batch : 490, D Loss : 3.320 | G Loss : 3.533
# Batch : 491, D Loss : 3.251 | G Loss : 3.546
# Batch : 492, D Loss : 3.274 | G Loss : 3.082
# Batch : 493, D Loss : 3.390 | G Loss : 3.478
# Batch : 494, D Loss : 3.421 | G Loss : 3.042
# Batch : 495, D Loss : 3.358 | G Loss : 3.666
# Batch : 496, D Loss : 3.391 | G Loss : 4.151
# Batch : 497, D Loss : 3.406 | G Loss : 4.019
# Batch : 498, D Loss : 3.358 | G Loss : 2.938
# Batch : 499, D Loss : 3.383 | G Loss : 3.583
# Batch : 500, D Loss : 3.322 | G Loss : 3.184
# Batch : 501, D Loss : 3.373 | G Loss : 3.490
# Batch : 502, D Loss : 3.349 | G Loss : 3.841
# Batch : 503, D Loss : 3.324 | G Loss : 3.012
# Batch : 504, D Loss : 3.455 | G Loss : 3.386
# Batch : 505, D Loss : 3.406 | G Loss : 3.222
# Batch : 506, D Loss : 3.298 | G Loss : 4.784
# Batch : 507, D Loss : 3.366 | G Loss : 3.765
# Batch : 508, D Loss : 3.397 | G Loss : 3.949
# Batch : 509, D Loss : 3.358 | G Loss : 2.945
# Batch : 510, D Loss : 3.232 | G Loss : 5.128
# Batch : 511, D Loss : 3.457 | G Loss : 3.929
# Batch : 512, D Loss : 3.423 | G Loss : 3.593
# Batch : 513, D Loss : 3.370 | G Loss : 4.255
# Batch : 514, D Loss : 3.304 | G Loss : 3.878
# Batch : 515, D Loss : 3.280 | G Loss : 3.718
# Batch : 516, D Loss : 3.415 | G Loss : 3.126
# Batch : 517, D Loss : 3.359 | G Loss : 4.422
# Batch : 518, D Loss : 3.381 | G Loss : 2.826
# Batch : 519, D Loss : 3.359 | G Loss : 3.373
# Batch : 520, D Loss : 3.190 | G Loss : 3.160
# Batch : 521, D Loss : 3.254 | G Loss : 3.052
# Batch : 522, D Loss : 3.412 | G Loss : 2.765
# Batch : 523, D Loss : 3.392 | G Loss : 3.242
# Batch : 524, D Loss : 3.376 | G Loss : 3.239
# Batch : 525, D Loss : 3.446 | G Loss : 2.985
# Batch : 526, D Loss : 3.456 | G Loss : 3.191
# Batch : 527, D Loss : 3.435 | G Loss : 2.949
# Batch : 528, D Loss : 3.377 | G Loss : 3.219
# Batch : 529, D Loss : 3.328 | G Loss : 3.508
# Batch : 530, D Loss : 3.298 | G Loss : 3.510
# Batch : 531, D Loss : 3.359 | G Loss : 3.687
# Batch : 532, D Loss : 3.320 | G Loss : 3.293
# Batch : 533, D Loss : 3.268 | G Loss : 4.081
# Batch : 534, D Loss : 3.310 | G Loss : 3.835
# Batch : 535, D Loss : 3.362 | G Loss : 3.187
# Batch : 536, D Loss : 3.425 | G Loss : 3.045
# Batch : 537, D Loss : 3.292 | G Loss : 3.397
# Batch : 538, D Loss : 3.377 | G Loss : 3.503
# Batch : 539, D Loss : 3.226 | G Loss : 3.696
# Batch : 540, D Loss : 3.383 | G Loss : 3.417
# Batch : 541, D Loss : 3.393 | G Loss : 3.228
# Batch : 542, D Loss : 3.346 | G Loss : 2.764
# Batch : 543, D Loss : 3.446 | G Loss : 3.320
# Batch : 544, D Loss : 3.298 | G Loss : 4.112
# Batch : 545, D Loss : 3.427 | G Loss : 3.050
# Batch : 546, D Loss : 3.436 | G Loss : 3.150
# Batch : 547, D Loss : 3.369 | G Loss : 3.271
# Batch : 548, D Loss : 3.343 | G Loss : 3.144
# Batch : 549, D Loss : 3.239 | G Loss : 3.376
# Batch : 550, D Loss : 3.365 | G Loss : 2.908
# Batch : 551, D Loss : 3.400 | G Loss : 3.294
# Batch : 552, D Loss : 3.316 | G Loss : 3.575
# Batch : 553, D Loss : 3.330 | G Loss : 2.950
# Batch : 554, D Loss : 3.340 | G Loss : 3.543
# Batch : 555, D Loss : 3.367 | G Loss : 3.328
# Batch : 556, D Loss : 3.247 | G Loss : 3.620
# Batch : 557, D Loss : 3.414 | G Loss : 3.142
# Batch : 558, D Loss : 3.424 | G Loss : 3.582
# Batch : 559, D Loss : 3.357 | G Loss : 3.077
# Batch : 560, D Loss : 3.382 | G Loss : 2.908
# Batch : 561, D Loss : 3.364 | G Loss : 2.977
# Batch : 562, D Loss : 3.366 | G Loss : 2.801
# Batch : 563, D Loss : 3.321 | G Loss : 3.422
# Batch : 564, D Loss : 3.338 | G Loss : 3.527
# Batch : 565, D Loss : 3.391 | G Loss : 4.139
# Batch : 566, D Loss : 3.358 | G Loss : 2.972
# Batch : 567, D Loss : 3.361 | G Loss : 3.127
# Batch : 568, D Loss : 3.347 | G Loss : 3.190
# Batch : 569, D Loss : 3.345 | G Loss : 3.184
# Batch : 570, D Loss : 3.325 | G Loss : 3.311
# Batch : 571, D Loss : 3.320 | G Loss : 3.134
# Batch : 572, D Loss : 3.364 | G Loss : 3.322
# Batch : 573, D Loss : 3.269 | G Loss : 3.374
# Batch : 574, D Loss : 3.379 | G Loss : 3.376
# Batch : 575, D Loss : 3.281 | G Loss : 3.581
# Batch : 576, D Loss : 3.368 | G Loss : 3.189
# Batch : 577, D Loss : 3.371 | G Loss : 3.249
# Batch : 578, D Loss : 3.360 | G Loss : 3.610
# Batch : 579, D Loss : 3.327 | G Loss : 3.419
# Batch : 580, D Loss : 3.310 | G Loss : 3.270
# Batch : 581, D Loss : 3.349 | G Loss : 3.592
# Batch : 582, D Loss : 3.396 | G Loss : 3.739
# Batch : 583, D Loss : 3.389 | G Loss : 2.646
# Batch : 584, D Loss : 3.409 | G Loss : 2.748
# Batch : 585, D Loss : 3.386 | G Loss : 3.400
# Batch : 586, D Loss : 3.393 | G Loss : 3.123
# Batch : 587, D Loss : 3.321 | G Loss : 3.187
# Batch : 588, D Loss : 3.378 | G Loss : 4.014
# Batch : 589, D Loss : 3.364 | G Loss : 3.288
# Batch : 590, D Loss : 3.321 | G Loss : 3.347
# Batch : 591, D Loss : 3.372 | G Loss : 3.014
# Batch : 592, D Loss : 3.351 | G Loss : 2.734
# Batch : 593, D Loss : 3.335 | G Loss : 2.711
# Batch : 594, D Loss : 3.291 | G Loss : 3.349
# Batch : 595, D Loss : 3.331 | G Loss : 3.447
# Batch : 596, D Loss : 3.443 | G Loss : 3.185
# Batch : 597, D Loss : 3.349 | G Loss : 3.219
# Batch : 598, D Loss : 3.402 | G Loss : 3.264
# Batch : 599, D Loss : 3.397 | G Loss : 3.572
# Batch : 600, D Loss : 3.366 | G Loss : 3.185
# Batch : 601, D Loss : 3.337 | G Loss : 2.649
# Batch : 602, D Loss : 3.336 | G Loss : 3.539
# Batch : 603, D Loss : 3.332 | G Loss : 2.942
# Batch : 604, D Loss : 3.371 | G Loss : 3.243
# Batch : 605, D Loss : 3.401 | G Loss : 3.522
# Batch : 606, D Loss : 3.395 | G Loss : 2.551
# Batch : 607, D Loss : 3.395 | G Loss : 2.982
# Batch : 608, D Loss : 3.328 | G Loss : 3.641
# Batch : 609, D Loss : 3.305 | G Loss : 3.256
# Batch : 610, D Loss : 3.328 | G Loss : 3.323
# Batch : 611, D Loss : 3.313 | G Loss : 3.041
# Batch : 612, D Loss : 3.336 | G Loss : 3.037
# Batch : 613, D Loss : 3.362 | G Loss : 3.217
# Batch : 614, D Loss : 3.295 | G Loss : 3.135
# Batch : 615, D Loss : 3.315 | G Loss : 3.639
# Batch : 616, D Loss : 3.394 | G Loss : 3.048
# Batch : 617, D Loss : 3.342 | G Loss : 2.890
# Batch : 618, D Loss : 3.345 | G Loss : 3.350
# Batch : 619, D Loss : 3.356 | G Loss : 3.603
# Batch : 620, D Loss : 3.376 | G Loss : 4.082
# Batch : 621, D Loss : 3.355 | G Loss : 3.298
# Batch : 622, D Loss : 3.333 | G Loss : 3.370
# Batch : 623, D Loss : 3.379 | G Loss : 2.883
# Batch : 624, D Loss : 3.281 | G Loss : 3.564
# Batch : 625, D Loss : 3.297 | G Loss : 3.779
# Batch : 626, D Loss : 3.365 | G Loss : 3.516
# Batch : 627, D Loss : 3.381 | G Loss : 3.017
# Batch : 628, D Loss : 3.352 | G Loss : 2.841
# Batch : 629, D Loss : 3.208 | G Loss : 3.880
# Batch : 630, D Loss : 3.408 | G Loss : 3.352
# Batch : 631, D Loss : 3.380 | G Loss : 3.528
# Batch : 632, D Loss : 3.381 | G Loss : 2.941
# Batch : 633, D Loss : 3.347 | G Loss : 2.796
# Batch : 634, D Loss : 3.277 | G Loss : 3.277
# Batch : 635, D Loss : 3.395 | G Loss : 3.447
# Batch : 636, D Loss : 3.344 | G Loss : 2.839
# Batch : 637, D Loss : 3.336 | G Loss : 4.112
# Batch : 638, D Loss : 3.371 | G Loss : 2.957
# Batch : 639, D Loss : 3.391 | G Loss : 4.204
# Batch : 640, D Loss : 3.376 | G Loss : 3.232
# Batch : 641, D Loss : 3.338 | G Loss : 3.046
# Batch : 642, D Loss : 3.367 | G Loss : 3.489
# Batch : 643, D Loss : 3.355 | G Loss : 4.451
# Batch : 644, D Loss : 3.361 | G Loss : 3.620
# Batch : 645, D Loss : 3.407 | G Loss : 3.097
# Batch : 646, D Loss : 3.402 | G Loss : 3.420
# Batch : 647, D Loss : 3.402 | G Loss : 3.205
# Batch : 648, D Loss : 3.409 | G Loss : 3.182
# Batch : 649, D Loss : 3.329 | G Loss : 3.389
# Batch : 650, D Loss : 3.318 | G Loss : 3.173
# Batch : 651, D Loss : 3.344 | G Loss : 3.581
# Batch : 652, D Loss : 3.362 | G Loss : 3.525
# Batch : 653, D Loss : 3.370 | G Loss : 3.193
# Batch : 654, D Loss : 3.363 | G Loss : 3.947
# Batch : 655, D Loss : 3.387 | G Loss : 2.832
# Batch : 656, D Loss : 3.295 | G Loss : 3.527
# Batch : 657, D Loss : 3.426 | G Loss : 3.128
# Batch : 658, D Loss : 3.367 | G Loss : 3.432
# Batch : 659, D Loss : 3.391 | G Loss : 2.987
# Batch : 660, D Loss : 3.371 | G Loss : 2.915
# Batch : 661, D Loss : 3.385 | G Loss : 2.692
# Batch : 662, D Loss : 3.329 | G Loss : 3.594
# Batch : 663, D Loss : 3.374 | G Loss : 3.074
# Batch : 664, D Loss : 3.377 | G Loss : 3.273
# Batch : 665, D Loss : 3.378 | G Loss : 3.251
# Batch : 666, D Loss : 3.304 | G Loss : 3.165
# Batch : 667, D Loss : 3.416 | G Loss : 2.994
# Batch : 668, D Loss : 3.367 | G Loss : 3.261
# Batch : 669, D Loss : 3.315 | G Loss : 3.202
# Batch : 670, D Loss : 3.359 | G Loss : 3.293
# Batch : 671, D Loss : 3.403 | G Loss : 2.982
# Batch : 672, D Loss : 3.306 | G Loss : 3.476
# Batch : 673, D Loss : 3.374 | G Loss : 3.337
# Batch : 674, D Loss : 3.424 | G Loss : 3.306
# Batch : 675, D Loss : 3.406 | G Loss : 3.239
# Batch : 676, D Loss : 3.319 | G Loss : 3.671
# Batch : 677, D Loss : 3.371 | G Loss : 3.009
# Batch : 678, D Loss : 3.365 | G Loss : 3.039
# Batch : 679, D Loss : 3.407 | G Loss : 2.899
# Batch : 680, D Loss : 3.383 | G Loss : 3.438
# Batch : 681, D Loss : 3.265 | G Loss : 3.370
# Batch : 682, D Loss : 3.390 | G Loss : 2.783
# Batch : 683, D Loss : 3.299 | G Loss : 3.171
# Batch : 684, D Loss : 3.382 | G Loss : 2.916
# Batch : 685, D Loss : 3.379 | G Loss : 3.106
# Batch : 686, D Loss : 3.340 | G Loss : 3.850
# Batch : 687, D Loss : 3.346 | G Loss : 3.842
# Batch : 688, D Loss : 3.376 | G Loss : 2.776
# Batch : 689, D Loss : 3.339 | G Loss : 3.108
# Batch : 690, D Loss : 3.310 | G Loss : 2.898
# Batch : 691, D Loss : 3.285 | G Loss : 3.077
# Batch : 692, D Loss : 3.346 | G Loss : 2.793
# Batch : 693, D Loss : 3.294 | G Loss : 3.998
# Batch : 694, D Loss : 3.408 | G Loss : 3.360
# Batch : 695, D Loss : 3.398 | G Loss : 2.992
# Batch : 696, D Loss : 3.393 | G Loss : 3.176
# Batch : 697, D Loss : 3.398 | G Loss : 3.113
# Batch : 698, D Loss : 3.346 | G Loss : 3.777
# Batch : 699, D Loss : 3.358 | G Loss : 3.387
# Batch : 700, D Loss : 3.367 | G Loss : 2.907
# Batch : 701, D Loss : 3.357 | G Loss : 2.616
# Batch : 702, D Loss : 3.381 | G Loss : 2.822
# Batch : 703, D Loss : 3.372 | G Loss : 2.913
# Batch : 704, D Loss : 3.388 | G Loss : 3.071
# Batch : 705, D Loss : 3.280 | G Loss : 3.210
# Batch : 706, D Loss : 3.358 | G Loss : 2.838
# Batch : 707, D Loss : 3.337 | G Loss : 3.260
# Batch : 708, D Loss : 3.331 | G Loss : 3.404
# Batch : 709, D Loss : 3.229 | G Loss : 3.520
# Batch : 710, D Loss : 3.285 | G Loss : 3.913
# Batch : 711, D Loss : 3.351 | G Loss : 3.814
# Batch : 712, D Loss : 3.437 | G Loss : 3.108
# Batch : 713, D Loss : 3.314 | G Loss : 3.090
# Batch : 714, D Loss : 3.288 | G Loss : 2.899
# Batch : 715, D Loss : 3.364 | G Loss : 2.884
# Batch : 716, D Loss : 3.380 | G Loss : 3.928
# Batch : 717, D Loss : 3.365 | G Loss : 3.958
# Batch : 718, D Loss : 3.330 | G Loss : 3.510
# Batch : 719, D Loss : 3.361 | G Loss : 2.892
# Batch : 720, D Loss : 3.355 | G Loss : 3.268
# Batch : 721, D Loss : 3.317 | G Loss : 2.854
# Batch : 722, D Loss : 3.329 | G Loss : 4.034
# Batch : 723, D Loss : 3.296 | G Loss : 2.633
# Batch : 724, D Loss : 3.370 | G Loss : 2.813
# Batch : 725, D Loss : 3.264 | G Loss : 3.892
# Batch : 726, D Loss : 3.406 | G Loss : 3.303
# Batch : 727, D Loss : 3.427 | G Loss : 2.950
# Batch : 728, D Loss : 3.390 | G Loss : 2.910
# Batch : 729, D Loss : 3.399 | G Loss : 3.314
# Batch : 730, D Loss : 3.347 | G Loss : 2.732
# Batch : 731, D Loss : 3.288 | G Loss : 3.457
# Batch : 732, D Loss : 3.412 | G Loss : 3.117
# Batch : 733, D Loss : 3.421 | G Loss : 3.013
# Batch : 734, D Loss : 3.381 | G Loss : 2.618
# Batch : 735, D Loss : 3.351 | G Loss : 2.832
# Batch : 736, D Loss : 3.225 | G Loss : 3.255
# Batch : 737, D Loss : 3.409 | G Loss : 3.791
# Batch : 738, D Loss : 3.337 | G Loss : 3.508
# Batch : 739, D Loss : 3.291 | G Loss : 3.142
# Batch : 740, D Loss : 3.309 | G Loss : 4.057
# Batch : 741, D Loss : 3.247 | G Loss : 4.172
# Batch : 742, D Loss : 3.378 | G Loss : 2.890
# Batch : 743, D Loss : 3.383 | G Loss : 3.249
# Batch : 744, D Loss : 3.382 | G Loss : 3.487
# Batch : 745, D Loss : 3.408 | G Loss : 3.519
# Batch : 746, D Loss : 3.374 | G Loss : 3.644
# Batch : 747, D Loss : 3.398 | G Loss : 3.153
# Batch : 748, D Loss : 3.377 | G Loss : 2.772
# Batch : 749, D Loss : 3.366 | G Loss : 4.400
# Batch : 750, D Loss : 3.375 | G Loss : 3.090
# Batch : 751, D Loss : 3.380 | G Loss : 4.114
# Batch : 752, D Loss : 3.393 | G Loss : 3.413
# Batch : 753, D Loss : 3.405 | G Loss : 3.196
# Batch : 754, D Loss : 3.308 | G Loss : 3.237
# Batch : 755, D Loss : 3.309 | G Loss : 3.302
# Batch : 756, D Loss : 3.293 | G Loss : 3.190
# Batch : 757, D Loss : 3.332 | G Loss : 2.946
# Batch : 758, D Loss : 3.369 | G Loss : 3.071
# Batch : 759, D Loss : 3.345 | G Loss : 3.515
# Batch : 760, D Loss : 3.291 | G Loss : 3.868
# Batch : 761, D Loss : 3.371 | G Loss : 2.866
# Batch : 762, D Loss : 3.330 | G Loss : 3.270
# Batch : 763, D Loss : 3.319 | G Loss : 3.774
# Batch : 764, D Loss : 3.292 | G Loss : 2.975
# Batch : 765, D Loss : 3.289 | G Loss : 3.052
# Batch : 766, D Loss : 3.353 | G Loss : 3.590
# Batch : 767, D Loss : 3.304 | G Loss : 3.556
# Batch : 768, D Loss : 3.339 | G Loss : 2.959
# Batch : 769, D Loss : 3.226 | G Loss : 3.570
# Batch : 770, D Loss : 3.329 | G Loss : 2.803
# Batch : 771, D Loss : 3.395 | G Loss : 4.134
# Batch : 772, D Loss : 3.393 | G Loss : 3.396
# Batch : 773, D Loss : 3.418 | G Loss : 2.885
# Batch : 774, D Loss : 3.385 | G Loss : 3.127
# Batch : 775, D Loss : 3.331 | G Loss : 3.550
# Batch : 776, D Loss : 3.343 | G Loss : 2.756
# Batch : 777, D Loss : 3.305 | G Loss : 4.172
# Batch : 778, D Loss : 3.296 | G Loss : 3.074
# Batch : 779, D Loss : 3.305 | G Loss : 2.773
# Batch : 780, D Loss : 3.367 | G Loss : 3.077
# Batch : 781, D Loss : 3.342 | G Loss : 3.148
# Batch : 782, D Loss : 3.369 | G Loss : 2.676
# Batch : 783, D Loss : 3.343 | G Loss : 3.694
# Batch : 784, D Loss : 3.328 | G Loss : 3.200
# Batch : 785, D Loss : 3.339 | G Loss : 3.220
# Batch : 786, D Loss : 3.393 | G Loss : 3.264
# Batch : 787, D Loss : 3.393 | G Loss : 2.447
# Batch : 788, D Loss : 3.389 | G Loss : 3.686
# Batch : 789, D Loss : 3.276 | G Loss : 3.467
# Batch : 790, D Loss : 3.377 | G Loss : 2.733
# Batch : 791, D Loss : 3.356 | G Loss : 3.460
# Batch : 792, D Loss : 3.352 | G Loss : 3.058
# Batch : 793, D Loss : 3.329 | G Loss : 3.401
# Batch : 794, D Loss : 3.308 | G Loss : 2.752
# Batch : 795, D Loss : 3.340 | G Loss : 3.142
# Batch : 796, D Loss : 3.358 | G Loss : 3.268
# Batch : 797, D Loss : 3.431 | G Loss : 2.855
# Batch : 798, D Loss : 3.358 | G Loss : 3.241
# Batch : 799, D Loss : 3.302 | G Loss : 3.076
# Batch : 800, D Loss : 3.381 | G Loss : 3.333
# Batch : 801, D Loss : 3.345 | G Loss : 3.147
# Batch : 802, D Loss : 3.348 | G Loss : 3.301
# Batch : 803, D Loss : 3.378 | G Loss : 3.271
# Batch : 804, D Loss : 3.451 | G Loss : 2.937
# Batch : 805, D Loss : 3.340 | G Loss : 3.118
# Batch : 806, D Loss : 3.257 | G Loss : 3.308
# Batch : 807, D Loss : 3.253 | G Loss : 3.232
# Batch : 808, D Loss : 3.370 | G Loss : 3.412
# Batch : 809, D Loss : 3.424 | G Loss : 3.152
# Batch : 810, D Loss : 3.363 | G Loss : 3.386
# Batch : 811, D Loss : 3.404 | G Loss : 2.935
# Batch : 812, D Loss : 3.311 | G Loss : 2.897
# Batch : 813, D Loss : 3.351 | G Loss : 2.928
# Batch : 814, D Loss : 3.402 | G Loss : 2.738
# Batch : 815, D Loss : 3.308 | G Loss : 3.269
# Batch : 816, D Loss : 3.302 | G Loss : 3.312
# Batch : 817, D Loss : 3.326 | G Loss : 3.135
# Batch : 818, D Loss : 3.341 | G Loss : 2.455
# Batch : 819, D Loss : 3.307 | G Loss : 2.552
# Batch : 820, D Loss : 3.410 | G Loss : 3.443
# Batch : 821, D Loss : 3.441 | G Loss : 2.686
# Batch : 822, D Loss : 3.297 | G Loss : 3.209
# Batch : 823, D Loss : 3.357 | G Loss : 2.705
# Batch : 824, D Loss : 3.352 | G Loss : 2.664
# Batch : 825, D Loss : 3.290 | G Loss : 2.707
# Batch : 826, D Loss : 3.382 | G Loss : 3.598
# Batch : 827, D Loss : 3.388 | G Loss : 3.441
# Batch : 828, D Loss : 3.350 | G Loss : 3.275
# Batch : 829, D Loss : 3.438 | G Loss : 3.229
# Batch : 830, D Loss : 3.408 | G Loss : 3.708
# Batch : 831, D Loss : 3.421 | G Loss : 3.356
# Batch : 832, D Loss : 3.381 | G Loss : 3.361
# Batch : 833, D Loss : 3.322 | G Loss : 3.357
# Batch : 834, D Loss : 3.296 | G Loss : 3.361
# Batch : 835, D Loss : 3.342 | G Loss : 3.201
# Batch : 836, D Loss : 3.356 | G Loss : 3.396
# Batch : 837, D Loss : 3.370 | G Loss : 2.719
# Batch : 838, D Loss : 3.394 | G Loss : 2.585
# Batch : 839, D Loss : 3.276 | G Loss : 3.535
# Batch : 840, D Loss : 3.398 | G Loss : 2.900
# Batch : 841, D Loss : 3.346 | G Loss : 3.277
# Batch : 842, D Loss : 3.341 | G Loss : 4.186
# Batch : 843, D Loss : 3.317 | G Loss : 3.496
# Batch : 844, D Loss : 3.312 | G Loss : 2.985
# Batch : 845, D Loss : 3.331 | G Loss : 3.025
# Batch : 846, D Loss : 3.220 | G Loss : 3.016
# Batch : 847, D Loss : 3.263 | G Loss : 3.076
# Batch : 848, D Loss : 3.450 | G Loss : 2.914
# Batch : 849, D Loss : 3.438 | G Loss : 2.582
# Batch : 850, D Loss : 3.357 | G Loss : 3.404
# Batch : 851, D Loss : 3.337 | G Loss : 3.233
# Batch : 852, D Loss : 3.370 | G Loss : 3.983
# Batch : 853, D Loss : 3.327 | G Loss : 2.780
# Batch : 854, D Loss : 3.388 | G Loss : 3.275
# Batch : 855, D Loss : 3.328 | G Loss : 3.987
# Batch : 856, D Loss : 3.365 | G Loss : 3.200
# Batch : 857, D Loss : 3.363 | G Loss : 3.743
# Batch : 858, D Loss : 3.351 | G Loss : 2.997
# Batch : 859, D Loss : 3.353 | G Loss : 3.100
# Batch : 860, D Loss : 3.335 | G Loss : 3.988
# Batch : 861, D Loss : 3.323 | G Loss : 3.047
# Batch : 862, D Loss : 3.296 | G Loss : 3.743
# Batch : 863, D Loss : 3.275 | G Loss : 3.444
# Batch : 864, D Loss : 3.285 | G Loss : 3.195
# Batch : 865, D Loss : 3.392 | G Loss : 3.085
# Batch : 866, D Loss : 3.279 | G Loss : 3.236
# Batch : 867, D Loss : 3.368 | G Loss : 3.049
# Batch : 868, D Loss : 3.355 | G Loss : 3.176
# Batch : 869, D Loss : 3.364 | G Loss : 3.343
# Batch : 870, D Loss : 3.308 | G Loss : 3.117
# Batch : 871, D Loss : 3.277 | G Loss : 2.690
# Batch : 872, D Loss : 3.351 | G Loss : 3.130
# Batch : 873, D Loss : 3.354 | G Loss : 2.954
# Batch : 874, D Loss : 3.339 | G Loss : 2.935
# Batch : 875, D Loss : 3.331 | G Loss : 2.827
# Batch : 876, D Loss : 3.289 | G Loss : 3.219
# Batch : 877, D Loss : 3.416 | G Loss : 2.859
# Batch : 878, D Loss : 3.370 | G Loss : 3.503
# Batch : 879, D Loss : 3.438 | G Loss : 3.287
# Batch : 880, D Loss : 3.467 | G Loss : 2.557
# Batch : 881, D Loss : 3.374 | G Loss : 2.894
# Batch : 882, D Loss : 3.264 | G Loss : 3.058
# Batch : 883, D Loss : 3.295 | G Loss : 2.984
# Batch : 884, D Loss : 3.354 | G Loss : 3.397
# Batch : 885, D Loss : 3.423 | G Loss : 2.839
# Batch : 886, D Loss : 3.412 | G Loss : 3.222
# Batch : 887, D Loss : 3.356 | G Loss : 3.019
# Batch : 888, D Loss : 3.345 | G Loss : 2.971
# Batch : 889, D Loss : 3.368 | G Loss : 3.710
# Batch : 890, D Loss : 3.427 | G Loss : 2.825
# Batch : 891, D Loss : 3.355 | G Loss : 3.015
# Batch : 892, D Loss : 3.386 | G Loss : 3.324
# Batch : 893, D Loss : 3.285 | G Loss : 3.290
# Batch : 894, D Loss : 3.384 | G Loss : 2.835
# Batch : 895, D Loss : 3.390 | G Loss : 3.008
# Batch : 896, D Loss : 3.337 | G Loss : 3.252
# Batch : 897, D Loss : 3.314 | G Loss : 2.720
# Batch : 898, D Loss : 3.337 | G Loss : 3.406
# Batch : 899, D Loss : 3.326 | G Loss : 2.970
# Batch : 900, D Loss : 3.354 | G Loss : 3.267
# Batch : 901, D Loss : 3.442 | G Loss : 2.965
# Batch : 902, D Loss : 3.384 | G Loss : 2.926
# Batch : 903, D Loss : 3.282 | G Loss : 3.171
# Batch : 904, D Loss : 3.354 | G Loss : 3.149
# Batch : 905, D Loss : 3.295 | G Loss : 3.085
# Batch : 906, D Loss : 3.411 | G Loss : 3.163
# Batch : 907, D Loss : 3.392 | G Loss : 3.640
# Batch : 908, D Loss : 3.318 | G Loss : 3.192
# Batch : 909, D Loss : 3.431 | G Loss : 3.342
# Batch : 910, D Loss : 3.346 | G Loss : 2.882
# Batch : 911, D Loss : 3.355 | G Loss : 2.680
# Batch : 912, D Loss : 3.391 | G Loss : 2.479
# Batch : 913, D Loss : 3.311 | G Loss : 3.283
# Batch : 914, D Loss : 3.433 | G Loss : 3.367
# Batch : 915, D Loss : 3.379 | G Loss : 3.162
# Batch : 916, D Loss : 3.350 | G Loss : 2.601
# Batch : 917, D Loss : 3.310 | G Loss : 3.332
# Batch : 918, D Loss : 3.399 | G Loss : 3.009
# Batch : 919, D Loss : 3.356 | G Loss : 3.617
# Batch : 920, D Loss : 3.329 | G Loss : 3.204
# Batch : 921, D Loss : 3.353 | G Loss : 3.212
# Batch : 922, D Loss : 3.362 | G Loss : 3.068
# Batch : 923, D Loss : 3.241 | G Loss : 3.307
# Batch : 924, D Loss : 3.446 | G Loss : 2.522
# Batch : 925, D Loss : 3.328 | G Loss : 3.587
# Batch : 926, D Loss : 3.409 | G Loss : 2.584
# Batch : 927, D Loss : 3.341 | G Loss : 3.031
# Batch : 928, D Loss : 3.397 | G Loss : 2.585
# Batch : 929, D Loss : 3.311 | G Loss : 3.661
# Batch : 930, D Loss : 3.338 | G Loss : 3.889
# Batch : 931, D Loss : 3.384 | G Loss : 3.238
# Batch : 932, D Loss : 3.278 | G Loss : 3.753
# Batch : 933, D Loss : 3.274 | G Loss : 3.968
# Batch : 934, D Loss : 3.335 | G Loss : 3.044
# Batch : 935, D Loss : 3.360 | G Loss : 3.217
# Batch : 936, D Loss : 3.404 | G Loss : 2.888
# Batch : 937, D Loss : 3.365 | G Loss : 3.241
# Batch : 938, D Loss : 3.531 | G Loss : 3.760
# Batch : 939, D Loss : 3.493 | G Loss : 3.302
# Batch : 940, D Loss : 3.417 | G Loss : 3.128
# Batch : 941, D Loss : 3.280 | G Loss : 3.395
# Batch : 942, D Loss : 3.334 | G Loss : 3.085
# Batch : 943, D Loss : 3.309 | G Loss : 3.607
# Batch : 944, D Loss : 3.346 | G Loss : 3.348
# Batch : 945, D Loss : 3.396 | G Loss : 3.024
# Batch : 946, D Loss : 3.419 | G Loss : 3.219
# Batch : 947, D Loss : 3.427 | G Loss : 2.888
# Batch : 948, D Loss : 3.326 | G Loss : 3.042
# Batch : 949, D Loss : 3.398 | G Loss : 2.944
# Batch : 950, D Loss : 3.384 | G Loss : 3.788
# Batch : 951, D Loss : 3.370 | G Loss : 3.087
# Batch : 952, D Loss : 3.345 | G Loss : 2.560
# Batch : 953, D Loss : 3.350 | G Loss : 2.793
# Batch : 954, D Loss : 3.380 | G Loss : 3.400
# Batch : 955, D Loss : 3.397 | G Loss : 3.160
# Batch : 956, D Loss : 3.394 | G Loss : 2.748
# Batch : 957, D Loss : 3.374 | G Loss : 2.692
# Batch : 958, D Loss : 3.315 | G Loss : 3.123
# Batch : 959, D Loss : 3.315 | G Loss : 3.305
# Batch : 960, D Loss : 3.374 | G Loss : 2.911
# Batch : 961, D Loss : 3.347 | G Loss : 3.619
# Batch : 962, D Loss : 3.419 | G Loss : 2.915
# Batch : 963, D Loss : 3.330 | G Loss : 2.744
# Batch : 964, D Loss : 3.326 | G Loss : 2.726
# Batch : 965, D Loss : 3.339 | G Loss : 3.456
# Batch : 966, D Loss : 3.403 | G Loss : 3.047
# Batch : 967, D Loss : 3.355 | G Loss : 3.026
# Batch : 968, D Loss : 3.397 | G Loss : 2.753
# Batch : 969, D Loss : 3.313 | G Loss : 3.357
# Batch : 970, D Loss : 3.412 | G Loss : 2.764
# Batch : 971, D Loss : 3.303 | G Loss : 2.842
# Batch : 972, D Loss : 3.377 | G Loss : 2.938
# Batch : 973, D Loss : 3.349 | G Loss : 3.384
# Batch : 974, D Loss : 3.356 | G Loss : 2.979
# Batch : 975, D Loss : 3.379 | G Loss : 3.136
# Batch : 976, D Loss : 3.382 | G Loss : 3.563
# Batch : 977, D Loss : 3.210 | G Loss : 3.380
# Batch : 978, D Loss : 3.376 | G Loss : 2.773
# Batch : 979, D Loss : 3.368 | G Loss : 3.185
# Batch : 980, D Loss : 3.367 | G Loss : 2.808
# Batch : 981, D Loss : 3.326 | G Loss : 3.100
# Batch : 982, D Loss : 3.305 | G Loss : 3.167
# Batch : 983, D Loss : 3.312 | G Loss : 3.234
# Batch : 984, D Loss : 3.298 | G Loss : 2.938
# Batch : 985, D Loss : 3.273 | G Loss : 2.737
# Batch : 986, D Loss : 3.363 | G Loss : 3.502
# Batch : 987, D Loss : 3.346 | G Loss : 3.268
# Batch : 988, D Loss : 3.348 | G Loss : 3.007
# Batch : 989, D Loss : 3.392 | G Loss : 3.109
# Batch : 990, D Loss : 3.412 | G Loss : 2.400
# Batch : 991, D Loss : 3.373 | G Loss : 3.183
# Batch : 992, D Loss : 3.301 | G Loss : 3.221
# Batch : 993, D Loss : 3.348 | G Loss : 3.242
# Batch : 994, D Loss : 3.398 | G Loss : 2.777
# Batch : 995, D Loss : 3.288 | G Loss : 3.097
# Batch : 996, D Loss : 3.269 | G Loss : 2.924
# Batch : 997, D Loss : 3.354 | G Loss : 3.142
# Batch : 998, D Loss : 3.373 | G Loss : 3.143
# Batch : 999, D Loss : 3.339 | G Loss : 3.037
# Batch : 1000, D Loss : 3.352 | G Loss : 2.778
# Batch : 1001, D Loss : 3.251 | G Loss : 3.097
# Batch : 1002, D Loss : 3.299 | G Loss : 3.149
# Batch : 1003, D Loss : 3.308 | G Loss : 2.822
# Batch : 1004, D Loss : 3.341 | G Loss : 3.150
# Batch : 1005, D Loss : 3.308 | G Loss : 3.231
# Batch : 1006, D Loss : 3.380 | G Loss : 2.594
# Batch : 1007, D Loss : 3.346 | G Loss : 3.040
# Batch : 1008, D Loss : 3.357 | G Loss : 2.899
# Batch : 1009, D Loss : 3.298 | G Loss : 4.029
# Batch : 1010, D Loss : 3.416 | G Loss : 3.511
# Batch : 1011, D Loss : 3.435 | G Loss : 3.070
# Batch : 1012, D Loss : 3.339 | G Loss : 2.656
# Batch : 1013, D Loss : 3.351 | G Loss : 3.208
# Batch : 1014, D Loss : 3.313 | G Loss : 2.652
# Batch : 1015, D Loss : 3.287 | G Loss : 3.062
# Batch : 1016, D Loss : 3.227 | G Loss : 3.758
# Batch : 1017, D Loss : 3.281 | G Loss : 2.908
# Batch : 1018, D Loss : 3.322 | G Loss : 2.764
# Batch : 1019, D Loss : 3.425 | G Loss : 2.882
# Batch : 1020, D Loss : 3.345 | G Loss : 3.135
# Batch : 1021, D Loss : 3.384 | G Loss : 2.824
# Batch : 1022, D Loss : 3.401 | G Loss : 2.756
# Batch : 1023, D Loss : 3.392 | G Loss : 3.543
# Batch : 1024, D Loss : 3.302 | G Loss : 3.322
# Batch : 1025, D Loss : 3.263 | G Loss : 2.700
# Batch : 1026, D Loss : 3.360 | G Loss : 3.157
# Batch : 1027, D Loss : 3.344 | G Loss : 3.722
# Batch : 1028, D Loss : 3.301 | G Loss : 3.079
# Batch : 1029, D Loss : 3.323 | G Loss : 2.828
# Batch : 1030, D Loss : 3.329 | G Loss : 3.926
# Batch : 1031, D Loss : 3.372 | G Loss : 2.887
# Batch : 1032, D Loss : 3.329 | G Loss : 3.271
# Batch : 1033, D Loss : 3.271 | G Loss : 3.297
# Batch : 1034, D Loss : 3.321 | G Loss : 2.973
# Batch : 1035, D Loss : 3.287 | G Loss : 2.980
# Batch : 1036, D Loss : 3.319 | G Loss : 3.034
# Batch : 1037, D Loss : 3.288 | G Loss : 3.251
# Batch : 1038, D Loss : 3.309 | G Loss : 2.613
# Batch : 1039, D Loss : 3.337 | G Loss : 3.072
# Batch : 1040, D Loss : 3.340 | G Loss : 2.625
# Batch : 1041, D Loss : 3.347 | G Loss : 3.050
# Batch : 1042, D Loss : 3.256 | G Loss : 3.175
# Batch : 1043, D Loss : 3.321 | G Loss : 2.782
# Batch : 1044, D Loss : 3.412 | G Loss : 2.533
# Batch : 1045, D Loss : 3.288 | G Loss : 3.213
# Batch : 1046, D Loss : 3.346 | G Loss : 3.061
# Batch : 1047, D Loss : 3.418 | G Loss : 2.663
# Batch : 1048, D Loss : 3.370 | G Loss : 2.921
# Batch : 1049, D Loss : 3.365 | G Loss : 3.023
# Batch : 1050, D Loss : 3.343 | G Loss : 3.308
# Batch : 1051, D Loss : 3.367 | G Loss : 2.789
# Batch : 1052, D Loss : 3.358 | G Loss : 3.354
# Batch : 1053, D Loss : 3.318 | G Loss : 2.903
# Batch : 1054, D Loss : 3.353 | G Loss : 2.829
# ...
# Batch : 62, D Loss : 3.251 | G Loss : 2.576
# Batch : 63, D Loss : 3.444 | G Loss : 2.588
# Batch : 64, D Loss : 3.363 | G Loss : 2.693
# Batch : 65, D Loss : 3.395 | G Loss : 2.669
# Batch : 66, D Loss : 3.320 | G Loss : 2.402
# Batch : 67, D Loss : 3.240 | G Loss : 3.039
# Batch : 68, D Loss : 3.262 | G Loss : 2.622
# Batch : 69, D Loss : 3.314 | G Loss : 2.453
# Batch : 70, D Loss : 3.391 | G Loss : 2.778
# Batch : 71, D Loss : 3.300 | G Loss : 2.548
# Batch : 72, D Loss : 3.339 | G Loss : 2.507
# Batch : 73, D Loss : 3.343 | G Loss : 2.438
# Batch : 74, D Loss : 3.384 | G Loss : 2.567
# Batch : 75, D Loss : 3.369 | G Loss : 2.538
# Batch : 76, D Loss : 3.315 | G Loss : 2.594
# Batch : 77, D Loss : 3.284 | G Loss : 3.098
# Batch : 78, D Loss : 3.291 | G Loss : 2.442
# Batch : 79, D Loss : 3.357 | G Loss : 2.364
# Batch : 80, D Loss : 3.240 | G Loss : 3.042
# Batch : 81, D Loss : 3.365 | G Loss : 2.527
# Batch : 82, D Loss : 3.398 | G Loss : 2.798
# Batch : 83, D Loss : 3.314 | G Loss : 2.648
# Batch : 84, D Loss : 3.366 | G Loss : 2.530
# Batch : 85, D Loss : 3.347 | G Loss : 2.732
# Batch : 86, D Loss : 3.262 | G Loss : 2.704
# Batch : 87, D Loss : 3.284 | G Loss : 2.791
# Batch : 88, D Loss : 3.335 | G Loss : 2.767
# Batch : 89, D Loss : 3.377 | G Loss : 2.473
# Batch : 90, D Loss : 3.345 | G Loss : 2.348
# Batch : 91, D Loss : 3.341 | G Loss : 2.474
# Batch : 92, D Loss : 3.361 | G Loss : 2.659
# Batch : 93, D Loss : 3.377 | G Loss : 2.551
# Batch : 94, D Loss : 3.358 | G Loss : 2.739
# Batch : 95, D Loss : 3.413 | G Loss : 2.200
# Batch : 96, D Loss : 3.280 | G Loss : 2.642
# Batch : 97, D Loss : 3.302 | G Loss : 3.061
# Batch : 98, D Loss : 3.338 | G Loss : 2.606
# Batch : 99, D Loss : 3.403 | G Loss : 2.350
# Batch : 100, D Loss : 3.355 | G Loss : 2.882
# Batch : 101, D Loss : 3.384 | G Loss : 2.291
# Batch : 102, D Loss : 3.315 | G Loss : 2.659
# Batch : 103, D Loss : 3.323 | G Loss : 2.374
# Batch : 104, D Loss : 3.246 | G Loss : 2.642
# Batch : 105, D Loss : 3.426 | G Loss : 2.587
# Batch : 106, D Loss : 3.383 | G Loss : 3.028
# Batch : 107, D Loss : 3.383 | G Loss : 2.467
# Batch : 108, D Loss : 3.341 | G Loss : 2.561
# Batch : 109, D Loss : 3.449 | G Loss : 3.007
# Batch : 110, D Loss : 3.297 | G Loss : 2.432
# Batch : 111, D Loss : 3.317 | G Loss : 2.646
# Batch : 112, D Loss : 3.363 | G Loss : 2.473
# Batch : 113, D Loss : 3.328 | G Loss : 2.818
# Batch : 114, D Loss : 3.317 | G Loss : 3.051
# Batch : 115, D Loss : 3.366 | G Loss : 2.511
# Batch : 116, D Loss : 3.367 | G Loss : 2.415
# Batch : 117, D Loss : 3.330 | G Loss : 2.887
# Batch : 118, D Loss : 3.342 | G Loss : 2.119
# Batch : 119, D Loss : 3.391 | G Loss : 2.958
# Batch : 120, D Loss : 3.331 | G Loss : 2.482
# Batch : 121, D Loss : 3.372 | G Loss : 2.434
# Batch : 122, D Loss : 3.356 | G Loss : 2.380
# Batch : 123, D Loss : 3.388 | G Loss : 2.226
# Batch : 124, D Loss : 3.279 | G Loss : 2.863
# Batch : 125, D Loss : 3.345 | G Loss : 3.217
# Batch : 126, D Loss : 3.301 | G Loss : 2.380
# Batch : 127, D Loss : 3.324 | G Loss : 3.096
# Batch : 128, D Loss : 3.311 | G Loss : 2.678
# Batch : 129, D Loss : 3.375 | G Loss : 2.889
# Batch : 130, D Loss : 3.352 | G Loss : 2.408
# Batch : 131, D Loss : 3.310 | G Loss : 2.632
# Batch : 132, D Loss : 3.413 | G Loss : 2.911
# Batch : 133, D Loss : 3.300 | G Loss : 2.332
# Batch : 134, D Loss : 3.354 | G Loss : 2.462
# Batch : 135, D Loss : 3.372 | G Loss : 2.781
# Batch : 136, D Loss : 3.387 | G Loss : 2.617
# Batch : 137, D Loss : 3.338 | G Loss : 2.434
# Batch : 138, D Loss : 3.413 | G Loss : 2.857
# Batch : 139, D Loss : 3.458 | G Loss : 3.142
# Batch : 140, D Loss : 3.436 | G Loss : 2.842
# Batch : 141, D Loss : 3.372 | G Loss : 2.457
# Batch : 142, D Loss : 3.339 | G Loss : 3.004
# Batch : 143, D Loss : 3.417 | G Loss : 2.847
# Batch : 144, D Loss : 3.381 | G Loss : 2.677
# Batch : 145, D Loss : 3.331 | G Loss : 2.810
# Batch : 146, D Loss : 3.316 | G Loss : 2.734
# Batch : 147, D Loss : 3.281 | G Loss : 3.039
# Batch : 148, D Loss : 3.312 | G Loss : 2.558
# Batch : 149, D Loss : 3.340 | G Loss : 3.106
# Batch : 150, D Loss : 3.382 | G Loss : 2.420
# Batch : 151, D Loss : 3.246 | G Loss : 3.312
# Batch : 152, D Loss : 3.331 | G Loss : 2.755
# Batch : 153, D Loss : 3.329 | G Loss : 2.306
# Batch : 154, D Loss : 3.348 | G Loss : 2.625
# Batch : 155, D Loss : 3.342 | G Loss : 2.506
# Batch : 156, D Loss : 3.357 | G Loss : 2.866
# Batch : 157, D Loss : 3.322 | G Loss : 2.570
# Batch : 158, D Loss : 3.318 | G Loss : 2.593
# Batch : 159, D Loss : 3.401 | G Loss : 2.716
# Batch : 160, D Loss : 3.340 | G Loss : 2.648
# Batch : 161, D Loss : 3.331 | G Loss : 2.650
# Batch : 162, D Loss : 3.386 | G Loss : 2.655
# Batch : 163, D Loss : 3.427 | G Loss : 2.348
# Batch : 164, D Loss : 3.358 | G Loss : 2.970
# Batch : 165, D Loss : 3.343 | G Loss : 2.274
# Batch : 166, D Loss : 3.321 | G Loss : 2.394
# Batch : 167, D Loss : 3.282 | G Loss : 2.651
# Batch : 168, D Loss : 3.318 | G Loss : 2.530
# Batch : 169, D Loss : 3.343 | G Loss : 2.188
# Batch : 170, D Loss : 3.421 | G Loss : 2.880
# Batch : 171, D Loss : 3.329 | G Loss : 2.326
# Batch : 172, D Loss : 3.338 | G Loss : 2.321
# Batch : 173, D Loss : 3.284 | G Loss : 3.150
# Batch : 174, D Loss : 3.323 | G Loss : 2.634
# Batch : 175, D Loss : 3.331 | G Loss : 2.783
# Batch : 176, D Loss : 3.352 | G Loss : 2.524
# Batch : 177, D Loss : 3.360 | G Loss : 2.613
# Batch : 178, D Loss : 3.324 | G Loss : 2.806
# Batch : 179, D Loss : 3.429 | G Loss : 2.547
# Batch : 180, D Loss : 3.372 | G Loss : 2.508
# Batch : 181, D Loss : 3.345 | G Loss : 2.526
# Batch : 182, D Loss : 3.295 | G Loss : 2.509
# Batch : 183, D Loss : 3.340 | G Loss : 2.556
# Batch : 184, D Loss : 3.404 | G Loss : 2.476
# Batch : 185, D Loss : 3.381 | G Loss : 2.149
# Batch : 186, D Loss : 3.348 | G Loss : 2.167
# Batch : 187, D Loss : 3.319 | G Loss : 2.126
# Batch : 188, D Loss : 3.338 | G Loss : 2.512
# Batch : 189, D Loss : 3.315 | G Loss : 2.585
# Batch : 190, D Loss : 3.297 | G Loss : 2.568
# Batch : 191, D Loss : 3.355 | G Loss : 2.359
# Batch : 192, D Loss : 3.240 | G Loss : 3.054
# Batch : 193, D Loss : 3.388 | G Loss : 2.352
# Batch : 194, D Loss : 3.347 | G Loss : 2.138
# Batch : 195, D Loss : 3.343 | G Loss : 2.648
# Batch : 196, D Loss : 3.321 | G Loss : 2.749
# Batch : 197, D Loss : 3.343 | G Loss : 2.553
# Batch : 198, D Loss : 3.306 | G Loss : 2.298
# Batch : 199, D Loss : 3.367 | G Loss : 2.400
# Batch : 200, D Loss : 3.332 | G Loss : 2.951
# Batch : 201, D Loss : 3.399 | G Loss : 2.664
# Batch : 202, D Loss : 3.308 | G Loss : 2.541
# Batch : 203, D Loss : 3.388 | G Loss : 2.476
# Batch : 204, D Loss : 3.290 | G Loss : 2.168
# Batch : 205, D Loss : 3.347 | G Loss : 2.809
# Batch : 206, D Loss : 3.386 | G Loss : 2.325
# Batch : 207, D Loss : 3.298 | G Loss : 3.106
# Batch : 208, D Loss : 3.344 | G Loss : 2.311
# Batch : 209, D Loss : 3.350 | G Loss : 2.298
# Batch : 210, D Loss : 3.281 | G Loss : 2.694
# Batch : 211, D Loss : 3.314 | G Loss : 2.473
# Batch : 212, D Loss : 3.265 | G Loss : 2.570
# Batch : 213, D Loss : 3.395 | G Loss : 2.627
# Batch : 214, D Loss : 3.264 | G Loss : 2.532
# Batch : 215, D Loss : 3.336 | G Loss : 2.635
# Batch : 216, D Loss : 3.344 | G Loss : 2.809
# Batch : 217, D Loss : 3.224 | G Loss : 2.545
# Batch : 218, D Loss : 3.321 | G Loss : 2.426
# Batch : 219, D Loss : 3.322 | G Loss : 2.632
# Batch : 220, D Loss : 3.390 | G Loss : 2.470
# Batch : 221, D Loss : 3.277 | G Loss : 2.285
# Batch : 222, D Loss : 3.300 | G Loss : 2.811
# Batch : 223, D Loss : 3.259 | G Loss : 2.460
# Batch : 224, D Loss : 3.381 | G Loss : 2.409
# Batch : 225, D Loss : 3.387 | G Loss : 2.484
# Batch : 226, D Loss : 3.341 | G Loss : 2.468
# Batch : 227, D Loss : 3.386 | G Loss : 2.258
# Batch : 228, D Loss : 3.374 | G Loss : 2.808
# Batch : 229, D Loss : 3.350 | G Loss : 2.589
# Batch : 230, D Loss : 3.358 | G Loss : 2.603
# Batch : 231, D Loss : 3.443 | G Loss : 2.332
# Batch : 232, D Loss : 3.380 | G Loss : 2.512
# Batch : 233, D Loss : 3.350 | G Loss : 2.466
# Batch : 234, D Loss : 3.340 | G Loss : 2.230
# Batch : 235, D Loss : 3.369 | G Loss : 2.341
# Batch : 236, D Loss : 3.318 | G Loss : 2.373
# Batch : 237, D Loss : 3.370 | G Loss : 2.409
# Batch : 238, D Loss : 3.374 | G Loss : 2.520
# Batch : 239, D Loss : 3.355 | G Loss : 2.338
# Batch : 240, D Loss : 3.355 | G Loss : 2.714
# Batch : 241, D Loss : 3.350 | G Loss : 2.359
# Batch : 242, D Loss : 3.273 | G Loss : 2.668
# Batch : 243, D Loss : 3.321 | G Loss : 2.368
# Batch : 244, D Loss : 3.315 | G Loss : 2.473
# Batch : 245, D Loss : 3.397 | G Loss : 2.601
# Batch : 246, D Loss : 3.282 | G Loss : 2.883
# Batch : 247, D Loss : 3.276 | G Loss : 2.329
# Batch : 248, D Loss : 3.323 | G Loss : 2.401
# Batch : 249, D Loss : 3.323 | G Loss : 2.766
# Batch : 250, D Loss : 3.367 | G Loss : 2.445
# Batch : 251, D Loss : 3.390 | G Loss : 2.278
# Batch : 252, D Loss : 3.284 | G Loss : 2.198
# Batch : 253, D Loss : 3.394 | G Loss : 2.361
# Batch : 254, D Loss : 3.356 | G Loss : 2.771
# Batch : 255, D Loss : 3.351 | G Loss : 2.585
# Batch : 256, D Loss : 3.388 | G Loss : 2.593
# Batch : 257, D Loss : 3.332 | G Loss : 2.578
# Batch : 258, D Loss : 3.348 | G Loss : 2.536
# Batch : 259, D Loss : 3.358 | G Loss : 3.426
# Batch : 260, D Loss : 3.318 | G Loss : 2.384
# Batch : 261, D Loss : 3.382 | G Loss : 2.493
# Batch : 262, D Loss : 3.333 | G Loss : 2.251
# Batch : 263, D Loss : 3.328 | G Loss : 2.405
# Batch : 264, D Loss : 3.323 | G Loss : 2.400
# Batch : 265, D Loss : 3.313 | G Loss : 2.489
# Batch : 266, D Loss : 3.301 | G Loss : 2.754
# Batch : 267, D Loss : 3.365 | G Loss : 2.719
# Batch : 268, D Loss : 3.328 | G Loss : 2.416
# Batch : 269, D Loss : 3.431 | G Loss : 2.624
# Batch : 270, D Loss : 3.496 | G Loss : 3.131
# Batch : 271, D Loss : 3.441 | G Loss : 2.397
# Batch : 272, D Loss : 3.386 | G Loss : 2.382
# Batch : 273, D Loss : 3.370 | G Loss : 2.215
# Batch : 274, D Loss : 3.334 | G Loss : 2.738
# Batch : 275, D Loss : 3.260 | G Loss : 2.437
# Batch : 276, D Loss : 3.327 | G Loss : 2.319
# Batch : 277, D Loss : 3.369 | G Loss : 2.477
# Batch : 278, D Loss : 3.323 | G Loss : 2.757
# Batch : 279, D Loss : 3.382 | G Loss : 2.505
# Batch : 280, D Loss : 3.388 | G Loss : 2.471
# Batch : 281, D Loss : 3.328 | G Loss : 2.360
# Batch : 282, D Loss : 3.411 | G Loss : 2.109
# Batch : 283, D Loss : 3.370 | G Loss : 2.241
# Batch : 284, D Loss : 3.319 | G Loss : 2.162
# Batch : 285, D Loss : 3.302 | G Loss : 2.587
# Batch : 286, D Loss : 3.273 | G Loss : 2.602
# Batch : 287, D Loss : 3.205 | G Loss : 3.051
# Batch : 288, D Loss : 3.331 | G Loss : 2.479
# Batch : 289, D Loss : 3.338 | G Loss : 2.993
# Batch : 290, D Loss : 3.389 | G Loss : 2.526
# Batch : 291, D Loss : 3.308 | G Loss : 3.013
# Batch : 292, D Loss : 3.303 | G Loss : 2.830
# Batch : 293, D Loss : 3.363 | G Loss : 2.596
# Batch : 294, D Loss : 3.369 | G Loss : 2.571
# Batch : 295, D Loss : 3.315 | G Loss : 2.627
# Batch : 296, D Loss : 3.389 | G Loss : 2.265
# Batch : 297, D Loss : 3.356 | G Loss : 2.683
# Batch : 298, D Loss : 3.346 | G Loss : 2.723
# Batch : 299, D Loss : 3.348 | G Loss : 2.639
# Batch : 300, D Loss : 3.357 | G Loss : 2.453
# Batch : 301, D Loss : 3.362 | G Loss : 2.034
# Batch : 302, D Loss : 3.363 | G Loss : 2.554
# Batch : 303, D Loss : 3.365 | G Loss : 2.208
# Batch : 304, D Loss : 3.404 | G Loss : 2.141
# Batch : 305, D Loss : 3.338 | G Loss : 2.339
# Batch : 306, D Loss : 3.392 | G Loss : 2.660
# Batch : 307, D Loss : 3.289 | G Loss : 2.559
# Batch : 308, D Loss : 3.352 | G Loss : 3.133
# Batch : 309, D Loss : 3.450 | G Loss : 2.438
# Batch : 310, D Loss : 3.395 | G Loss : 2.409
# Batch : 311, D Loss : 3.279 | G Loss : 2.637
# Batch : 312, D Loss : 3.332 | G Loss : 2.554
# Batch : 313, D Loss : 3.361 | G Loss : 2.244
# Batch : 314, D Loss : 3.385 | G Loss : 2.595
# Batch : 315, D Loss : 3.354 | G Loss : 2.950
# Batch : 316, D Loss : 3.357 | G Loss : 2.297
# Batch : 317, D Loss : 3.316 | G Loss : 2.688
# Batch : 318, D Loss : 3.340 | G Loss : 2.406
# Batch : 319, D Loss : 3.394 | G Loss : 2.950
# Batch : 320, D Loss : 3.288 | G Loss : 3.038
# Batch : 321, D Loss : 3.345 | G Loss : 2.417
# Batch : 322, D Loss : 3.311 | G Loss : 2.924
# Batch : 323, D Loss : 3.337 | G Loss : 2.709
# Batch : 324, D Loss : 3.264 | G Loss : 2.363
# Batch : 325, D Loss : 3.371 | G Loss : 2.512
# Batch : 326, D Loss : 3.308 | G Loss : 2.553
# Batch : 327, D Loss : 3.358 | G Loss : 2.418
# Batch : 328, D Loss : 3.356 | G Loss : 2.196
# Batch : 329, D Loss : 3.351 | G Loss : 2.383
# Batch : 330, D Loss : 3.371 | G Loss : 2.653
# Batch : 331, D Loss : 3.301 | G Loss : 2.343
# Batch : 332, D Loss : 3.413 | G Loss : 2.953
# Batch : 333, D Loss : 3.299 | G Loss : 2.228
# Batch : 334, D Loss : 3.362 | G Loss : 2.513
# Batch : 335, D Loss : 3.339 | G Loss : 2.271
# Batch : 336, D Loss : 3.442 | G Loss : 2.232
# Batch : 337, D Loss : 3.408 | G Loss : 2.418
# Batch : 338, D Loss : 3.325 | G Loss : 2.267
# Batch : 339, D Loss : 3.407 | G Loss : 2.799
# Batch : 340, D Loss : 3.374 | G Loss : 2.890
# Batch : 341, D Loss : 3.381 | G Loss : 2.763
# Batch : 342, D Loss : 3.376 | G Loss : 2.334
# Batch : 343, D Loss : 3.269 | G Loss : 2.802
# Batch : 344, D Loss : 3.337 | G Loss : 2.494
# Batch : 345, D Loss : 3.395 | G Loss : 2.405
# Batch : 346, D Loss : 3.356 | G Loss : 2.536
# Batch : 347, D Loss : 3.261 | G Loss : 2.268
# Batch : 348, D Loss : 3.377 | G Loss : 2.816
# Batch : 349, D Loss : 3.388 | G Loss : 2.418
# Batch : 350, D Loss : 3.331 | G Loss : 2.849
# Batch : 351, D Loss : 3.368 | G Loss : 2.568
# Batch : 352, D Loss : 3.214 | G Loss : 2.403
# Batch : 353, D Loss : 3.337 | G Loss : 3.286
# Batch : 354, D Loss : 3.308 | G Loss : 3.220
# Batch : 355, D Loss : 3.362 | G Loss : 2.406
# Batch : 356, D Loss : 3.358 | G Loss : 2.936
# Batch : 357, D Loss : 3.288 | G Loss : 2.426
# Batch : 358, D Loss : 3.337 | G Loss : 2.580
# Batch : 359, D Loss : 3.285 | G Loss : 2.776
# Batch : 360, D Loss : 3.309 | G Loss : 2.214
# Batch : 361, D Loss : 3.386 | G Loss : 2.163
# Batch : 362, D Loss : 3.411 | G Loss : 2.322
# Batch : 363, D Loss : 3.366 | G Loss : 2.346
# Batch : 364, D Loss : 3.380 | G Loss : 2.673
# Batch : 365, D Loss : 3.358 | G Loss : 2.211
# Batch : 366, D Loss : 3.317 | G Loss : 2.624
# Batch : 367, D Loss : 3.311 | G Loss : 2.336
# Batch : 368, D Loss : 3.375 | G Loss : 2.229
# Batch : 369, D Loss : 3.299 | G Loss : 2.900
# Batch : 370, D Loss : 3.392 | G Loss : 2.430
# Batch : 371, D Loss : 3.403 | G Loss : 2.279
# Batch : 372, D Loss : 3.337 | G Loss : 2.229
# Batch : 373, D Loss : 3.346 | G Loss : 2.524
# Batch : 374, D Loss : 3.306 | G Loss : 2.511
# Batch : 375, D Loss : 3.410 | G Loss : 2.117
# Batch : 376, D Loss : 3.347 | G Loss : 2.929
# Batch : 377, D Loss : 3.342 | G Loss : 2.568
# Batch : 378, D Loss : 3.372 | G Loss : 2.100
# Batch : 379, D Loss : 3.400 | G Loss : 3.358
# Batch : 380, D Loss : 3.334 | G Loss : 2.715
# Batch : 381, D Loss : 3.417 | G Loss : 2.360
# Batch : 382, D Loss : 3.370 | G Loss : 2.270
# Batch : 383, D Loss : 3.343 | G Loss : 2.266
# Batch : 384, D Loss : 3.278 | G Loss : 2.417
# Batch : 385, D Loss : 3.337 | G Loss : 3.278
# Batch : 386, D Loss : 3.382 | G Loss : 2.303
# Batch : 387, D Loss : 3.261 | G Loss : 2.691
# Batch : 388, D Loss : 3.286 | G Loss : 2.703
# Batch : 389, D Loss : 3.331 | G Loss : 2.449
# Batch : 390, D Loss : 3.321 | G Loss : 2.472
# Batch : 391, D Loss : 3.332 | G Loss : 2.735
# Batch : 392, D Loss : 3.408 | G Loss : 2.550
# Batch : 393, D Loss : 3.342 | G Loss : 3.570
# Batch : 394, D Loss : 3.412 | G Loss : 2.581
# Batch : 395, D Loss : 3.355 | G Loss : 2.715
# Batch : 396, D Loss : 3.352 | G Loss : 2.090
# Batch : 397, D Loss : 3.338 | G Loss : 2.452
# Batch : 398, D Loss : 3.391 | G Loss : 2.461
# Batch : 399, D Loss : 3.307 | G Loss : 2.662
# Batch : 400, D Loss : 3.266 | G Loss : 2.455
# Batch : 401, D Loss : 3.376 | G Loss : 2.776
# Batch : 402, D Loss : 3.398 | G Loss : 2.838
# Batch : 403, D Loss : 3.391 | G Loss : 2.667
# Batch : 404, D Loss : 3.385 | G Loss : 2.665
# Batch : 405, D Loss : 3.351 | G Loss : 2.424
# Batch : 406, D Loss : 3.267 | G Loss : 2.516
# Batch : 407, D Loss : 3.429 | G Loss : 3.212
# Batch : 408, D Loss : 3.390 | G Loss : 3.214
# Batch : 409, D Loss : 3.444 | G Loss : 2.588
# Batch : 410, D Loss : 3.328 | G Loss : 2.464
# Batch : 411, D Loss : 3.360 | G Loss : 2.118
# Batch : 412, D Loss : 3.218 | G Loss : 2.551
# Batch : 413, D Loss : 3.363 | G Loss : 2.855
# Batch : 414, D Loss : 3.327 | G Loss : 3.008
# Batch : 415, D Loss : 3.424 | G Loss : 2.866
# Batch : 416, D Loss : 3.421 | G Loss : 2.293
# Batch : 417, D Loss : 3.341 | G Loss : 2.545
